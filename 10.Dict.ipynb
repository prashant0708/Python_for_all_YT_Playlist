# %%
student = {
    
    "name":"Prashant", 
    "Age":25,
    "Skill":["Python", "ML", "Genai"]
}

# %%
type(student)
# Out:
# dict

# %%
## Rules to define dict
1. Key must be unique
2. Key can be str, int , float , tuple 
3. Item (value)  can be any thing

# %%
student = {
    
    "name":"Prashant", 
    "Age":25,
    "Skill":["Python", "ML", "Genai"], 
    "name":"David"
}

# %%
student
# Out:
# {'name': 'David', 'Age': 25, 'Skill': ['Python', 'ML', 'Genai']}

# %%
## empty dict 

my_dict = {
    
}

# %%
type(my_dict)
# Out:
# dict

# %%
## define full flage dict 

my_dict = {
    "name" :["Prashant", "David", "Kushal", "Ashutosh"],
    "age":[20,30, 40 ], 
    "Skill":"Python", 
    "email":"Prashant@gmail.com", 
    "Pin code":23456
    
}

# %%
my_dict
# Out:
# {'name': ['Prashant', 'David', 'Kushal', 'Ashutosh'],
#  'age': [20, 30, 40],
#  'Skill': 'Python',
#  'email': 'Prashant@gmail.com',
#  'Pin code': 23456}

# %%
type(my_dict["name"])
# Out:
# list

# %%
my_dict['name'][::-1]
# Out:
# ['Ashutosh', 'Kushal', 'David', 'Prashant']

# %%
my_dict["age"].append(50)

# %%
my_dict["age"]
# Out:
# [20, 30, 40, 50]

# %%
my_dict
# Out:
# {'name': ['Prashant', 'David', 'Kushal', 'Ashutosh'],
#  'age': [20, 30, 40, 50],
#  'Skill': 'Python',
#  'email': 'Prashant@gmail.com',
#  'Pin code': 23456}

# %%
my_dict["Skill"]
# Out:
# 'Python'

# %%
my_dict['age'][2]=45

# %%
my_dict
# Out:
# {'name': ['Prashant', 'David', 'Kushal', 'Ashutosh'],
#  'age': [20, 30, 45, 50],
#  'Skill': 'Python',
#  'email': 'Prashant@gmail.com',
#  'Pin code': 23456}

# %%
my_dict["Skill"]="ML"

# %%
my_dict
# Out:
# {'name': ['Prashant', 'David', 'Kushal', 'Ashutosh'],
#  'age': [20, 30, 45, 50],
#  'Skill': 'ML',
#  'email': 'Prashant@gmail.com',
#  'Pin code': 23456}

# %%
### Change -- David to Ganesh

# %%
m1 = {
    "cloud":"AWS", 
    "Cicd":"Github_action", 
    "Language":"Python"
}

# %%
m1
# Out:
# {'Cloud': 'Aws', 'Language': 'Python', 'CICD': 'Github Action'}

# %%
my_dict.update(m1)

# %%
my_dict
# Out:
# {'name': ['Prashant', 'David', 'Kushal', 'Ashutosh'],
#  'age': [20, 30, 45, 50],
#  'Skill': 'ML',
#  'email': 'Prashant@gmail.com',
#  'Pin code': 23456,
#  'Cloud': 'Aws',
#  'Language': 'Python',
#  'CICD': 'Github Action'}

# %%
## remove the item from the dict 

del my_dict['Pin code']

# %%
my_dict
# Out:
# {'name': ['Prashant', 'David', 'Kushal', 'Ashutosh'],
#  'age': [20, 30, 45, 50],
#  'Skill': 'ML',
#  'email': 'Prashant@gmail.com',
#  'Cloud': 'Aws',
#  'Language': 'Python',
#  'CICD': 'Github Action'}

# %%
my_dict.pop('Cloud')
# Out:
# 'Aws'

# %%
my_dict.popitem()
# Out:
# ('CICD', 'Github Action')

# %%
my_dict
# Out:
# {'name': ['Prashant', 'David', 'Kushal', 'Ashutosh'],
#  'age': [20, 30, 45, 50],
#  'Skill': 'ML',
#  'email': 'Prashant@gmail.com',
#  'Language': 'Python'}

# %%
my_dict.clear()

# %%
my_dict
# Out:
# {}

# %%
## nasted dict 

user = {
    
    "name":"Prrashant", 
    "skill" : {"Language":["Python", "Java", "Sql"], "Database":["Mysql", "Mongodb"], "OS":"linux" , "Soft skill":{"Team building":"Colarative work", "Language":"English"}}, 
    "AI":["ML", "Deep learning", "Gen ai"]
}

# %%
user
# Out:
# {'name': 'Prrashant',
#  'skill': {'Language': ['Python', 'Java', 'Sql'],
#   'Database': ['Mysql', 'Mongodb'],
#   'OS': 'linux',
#   'Soft skill': {'Team building': 'Colarative work', 'Language': 'English'}},
#  'AI': ['ML', 'Deep learning', 'Gen ai']}

# %%
user['skill']
# Out:
# {'Language': ['Python', 'Java', 'Sql'],
#  'Database': ['Mysql', 'Mongodb'],
#  'OS': 'linux',
#  'Soft skill': {'Team building': 'Colarative work', 'Language': 'English'}}

# %%
user['skill']['Language']
# Out:
# ['Python', 'Java', 'Sql']

# %%
user['skill']['Soft skill']['Language']="Hindi"

# %%
user
# Out:
# {'name': 'Prrashant',
#  'skill': {'Language': ['Python', 'Java', 'Sql'],
#   'Database': ['Mysql', 'Mongodb'],
#   'OS': 'linux',
#   'Soft skill': {'Team building': 'Colarative work', 'Language': 'Hindi'}},
#  'AI': ['ML', 'Deep learning', 'Gen ai']}

# %%
del user

# %%
user
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 user
#
# NameError: name 'user' is not defined
