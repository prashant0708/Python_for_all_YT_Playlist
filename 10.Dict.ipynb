# %%
student = {
    "name":"Prashant", 
    "age":24,
    "Skill":"Python"
}

# %%
## empty dict

my_dict ={}

# %%
type(my_dict)
# Out:
# dict

# %%
mydict= {
    
    "name":["Prashant","David","Kushal","Ashitosh","Jon"], 
    "Age":[20,30,50,60], 
    "Skill" :"Python",
    "Email":"prashant@gmail.com", 
    "Pin code":345689
        }

# %%
type(mydict)
# Out:
# dict

# %%
mydict
# Out:
# {'name': ['Prashant', 'David', 'Kushal', 'Ashitosh', 'Jon'],
#  'Age': [20, 30, 50, 60],
#  'Skill': 'Python',
#  'Email': 'prashant@gmail.com',
#  'Pin code': 345689}

# %%
mydict["name"][::-1]
# Out:
# ['Jon', 'Ashitosh', 'Kushal', 'David', 'Prashant']

# %%
mydict["Skill"]
# Out:
# 'Python'

# %%
mydict['Age'].append(55)

# %%
type(mydict['Age'])
# Out:
# list

# %%
mydict['Age'][2]=45

# %%
mydict
# Out:
# {'name': ['Prashant', 'David', 'Kushal', 'Ashitosh', 'Jon'],
#  'Age': [20, 30, 45, 60, 55],
#  'Skill': 'Python',
#  'Email': 'prashant@gmail.com',
#  'Pin code': 345689}

# %%
mydict["Skill"]="ML"

# %%
mydict
# Out:
# {'name': ['Prashant', 'David', 'Kushal', 'Ashitosh', 'Jon'],
#  'Age': [20, 30, 45, 60, 55],
#  'Skill': 'ML',
#  'Email': 'prashant@gmail.com',
#  'Pin code': 345689}

# %%
# Ganesh

m1 = {
    "Cloud":"Aws",
    "Language":"Python",
    "CICD":"Github Action"
}

# %%
m1
# Out:
# {'Cloud': 'Aws', 'Language': 'Python', 'CICD': 'Github Action'}

# %%
mydict
# Out:
# {'name': ['Prashant', 'David', 'Kushal', 'Ashitosh', 'Jon'],
#  'Age': [20, 30, 45, 60, 55],
#  'Skill': 'ML',
#  'Email': 'prashant@gmail.com',
#  'Pin code': 345689}

# %%
mydict.update(m1)

# %%
mydict
# Out:
# {'name': ['Prashant', 'David', 'Kushal', 'Ashitosh', 'Jon'],
#  'Age': [20, 30, 45, 60, 55],
#  'Skill': 'ML',
#  'Email': 'prashant@gmail.com',
#  'Pin code': 345689,
#  'Cloud': 'Aws',
#  'Language': 'Python',
#  'CICD': 'Github Action'}

# %%
## remove some of the element
mydict.pop("Cloud")
# Out:
# 'Aws'

# %%
mydict
# Out:
# {'name': ['Prashant', 'David', 'Kushal', 'Ashitosh', 'Jon'],
#  'Age': [20, 30, 45, 60, 55],
#  'Skill': 'ML',
#  'Email': 'prashant@gmail.com',
#  'Pin code': 345689,
#  'Language': 'Python',
#  'CICD': 'Github Action'}

# %%
mydict.popitem()
# Out:
# ('CICD', 'Github Action')

# %%
mydict
# Out:
# {'name': ['Prashant', 'David', 'Kushal', 'Ashitosh', 'Jon'],
#  'Age': [20, 30, 45, 60, 55],
#  'Skill': 'ML',
#  'Email': 'prashant@gmail.com',
#  'Pin code': 345689,
#  'Language': 'Python'}

# %%
mydict.popitem()
# Out:
# ('Language', 'Python')

# %%
mydict
# Out:
# {'name': ['Prashant', 'David', 'Kushal', 'Ashitosh', 'Jon'],
#  'Age': [20, 30, 45, 60, 55],
#  'Skill': 'ML',
#  'Email': 'prashant@gmail.com',
#  'Pin code': 345689}

# %%
mydict.clear()

# %%
mydict
# Out:
# {}

# %%
my_dict= {'name': ['Prashant', 'David', 'Kushal', 'Ashitosh', 'Jon'],
 'Age': [20, 30, 45, 60, 55],
 'Skill': 'ML',
 'Email': 'prashant@gmail.com',
 'Pin code': 345689,
 'Language': 'Python',
 'CICD': 'Github Action'}

# %%
del my_dict["Email"]

# %%
my_dict
# Out:
# {'name': ['Prashant', 'David', 'Kushal', 'Ashitosh', 'Jon'],
#  'Age': [20, 30, 45, 60, 55],
#  'Skill': 'ML',
#  'Pin code': 345689,
#  'Language': 'Python',
#  'CICD': 'Github Action'}

# %%
## remove 

1. pop
2. popitem
3. clear
4. del <key>

# %%
## Nested Dict

user = {

    "name": "Prashant",

    "skill":{"Language":"Python","DataBae":["MSQL","SQL"],"AI":["ml","Genai","Deep learning","Agntic ai"]},

    "socal-handle":{1:"youtube",2:"Insta",3:"facebook",4:"linkdlin"}

    

}

# %%
user
# Out:
# {'name': 'Prashant',
#  'skill': {'Language': 'Python',
#   'DataBae': ['MSQL', 'SQL'],
#   'AI': ['ml', 'Genai', 'Deep learning', 'Agntic ai']},
#  'socal-handle': {1: 'youtube', 2: 'Insta', 3: 'facebook', 4: 'linkdlin'}}

# %%
type(user["skill"])
# Out:
# dict

# %%
type(user["skill"]['AI'])
# Out:
# list

# %%
user["socal-handle"][4]
# Out:
# 'linkdlin'

# %%
del user

# %%
user
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 user
#
# NameError: name 'user' is not defined
