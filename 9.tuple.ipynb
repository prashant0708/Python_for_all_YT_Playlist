# %% [markdown]
# # Tuple
# - Tuple is built-in data types of python which is used to store the hetrogenious and homogenious element.
# - Tuple in python is an ordered , immutable collection of elements.
# - Tuple is similar to list but it is not mutable.(element of the tuple can't changed)
# - Many function return tuple to provide the multiple value.

# %%
## create a tuple

t = "AWS","Data Science", "Mlops"

# %%
type(t)
# Out:
# tuple

# %%
t
# Out:
# ('AWS', 'Data Science', 'Mlops')

# %%
## create empty tuple
t2 =()

# %%
type(t2)
# Out:
# tuple

# %%
### create tuple with element

t3 = (23,56,78,"GenAI", "llm",56+23j)

# %%
type(t3)
# Out:
# tuple

# %%
l=[23,56,78,"GenAI", "llm",56+23j]

# %%
l[2]
# Out:
# 78

# %%
type(t3), type(l)
# Out:
# (tuple, list)

# %%
## change the element of the list

l[2]="Prashant"

# %%
l
# Out:
# [23, 56, 'Prashant', 'GenAI', 'llm', (56+23j)]

# %%
t3
# Out:
# (23, 56, 78, 'GenAI', 'llm', (56+23j))

# %%
t3[2]
# Out:
# 78

# %%
t3[2]="Prashant"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 t3[2]="Prashant"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t3
# Out:
# (23, 56, 78, 'GenAI', 'llm', (56+23j))

# %%
t3[2:5]
# Out:
# (78, 'GenAI', 'llm')

# %%
t3[-1]
# Out:
# (56+23j)

# %%
t3[-2]
# Out:
# 'llm'

# %%
t3[2:4]
# Out:
# (78, 'GenAI')

# %%
len(t3)
# Out:
# 6

# %%
t4 = (1,1,2,2,56,78,99,99)

# %%
type(t4)
# Out:
# tuple

# %%
t4.count(99)
# Out:
# 2

# %%
sum(t4)
# Out:
# 338

# %%
## minimum and maximum value of the tuple

min(t4)
# Out:
# 1

# %%
max(t4)
# Out:
# 99

# %%
t4
# Out:
# (1, 1, 2, 2, 56, 78, 99, 99)

# %%
t4*2
# Out:
# (1, 1, 2, 2, 56, 78, 99, 99, 1, 1, 2, 2, 56, 78, 99, 99)

# %%
l = [1, 1, 2, 2, 56, 78, 99, 99]

# %%
t5 = ( 56, 35, 99,1,4,2,6)

# %%
t5
# Out:
# (56, 35, 99, 1, 4, 2, 6)

# %%
x=sorted(t5)

# %%
x
# Out:
# [1, 2, 4, 6, 35, 56, 99]

# %%
type(x)
# Out:
# list

# %%
tuple(sorted(t5,reverse=True))
# Out:
# (99, 56, 35, 6, 4, 2, 1)

# %%
t5
# Out:
# (56, 35, 99, 1, 4, 2, 6)

# %%
l = list(t5)

# %%
l
# Out:
# [56, 35, 99, 1, 4, 2, 6]

# %%
type(l)
# Out:
# list

# %%
l[2]="Prashant"

# %%
l
# Out:
# [56, 35, 'Prashant', 1, 4, 2, 6]

# %%
t5 = tuple(l)

# %%
type(t5)
# Out:
# tuple

# %%
t5
# Out:
# (56, 35, 'Prashant', 1, 4, 2, 6)

# %%
t6 = (1,2,3,4,5,["Prashant","AWS","Mlops","Genai"])

# %%
type(t6)
# Out:
# tuple

# %%
## we know that tuple is immutable can we change the element of the nested list of tuple
t6[-1][1]="AZURE"

# %%
t6
# Out:
# (1, 2, 3, 4, 5, ['Prashant', 'AZURE', 'Mlops', 'Genai'])

# %%
t5
# Out:
# (56, 35, 'Prashant', 1, 4, 2, 6)

# %%
"AWS" in t5
# Out:
# False

# %%
"Prashant" in t5
# Out:
# True

# %%
t10 = (23,56,78,"Bangalore","Delhi", "Google","AWS","prashant")

# %%
## I WANT TO CHECK THE "Prashant" is available in the given tuple or not 


if ("Prashant" in t10) | ("prashant" in t10):
    print("Yes Prashant is available in the given tuple")
else:
    print("Yes Prashant is  not available in the given tuple")
# Out:
# Yes Prashant is available in the given tuple

# %%
## concatination of the tuple

t5
# Out:
# (56, 35, 'Prashant', 1, 4, 2, 6)

# %%
t4
# Out:
# (1, 1, 2, 2, 56, 78, 99, 99)

# %%
t4+t5
# Out:
# (1, 1, 2, 2, 56, 78, 99, 99, 56, 35, 'Prashant', 1, 4, 2, 6)

# %%
l
# Out:
# [56, 35, 'Prashant', 1, 4, 2, 6]

# %%
t3
# Out:
# (23, 56, 78, 'GenAI', 'llm', (56+23j))

# %%
t3+l
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 t3+l
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
t3.remove(23)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 t3.remove(2)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
t3.pop(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 t3.pop(2)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
del t3

# %%
t3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 t3
#
# NameError: name 't3' is not defined
