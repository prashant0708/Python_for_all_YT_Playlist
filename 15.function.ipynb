# %% [markdown]
# ## Function

# %%
## user enter the input , we check number is even or odd 

user_input = int(input("Enter the number = "))

if user_input % 2 == 0:
    print(user_input)
else:
    print("Not even")
# Out:
# Not even

# %%
def name (a):
    if a % 2 == 0:
        print(a)
    else:
        print("Not even")

# %%
name(44)
# Out:
# 44

# %%
def hello():
    result = "I am from function code"
    print(result)

# %%
x = hello()
# Out:
# I am from function code

# %%
hello()
hello()
hello()
hello()
# Out:
# I am from function code
# I am from function code
# I am from function code
# I am from function code

# %%
## find the area of circle using the function 

## area  = pai *radious*radious

def circle_area(r :int):
    area  = 3.14 *r*r
    print(f"Area of circle is {area}")

# %%
circle_area(23)
# Out:
# Area of circle is 1661.06

# %%
## diff b/w print and return

def sums(a,b):
    result = a+b
    return result

# %%
x = sums(10,20)

# %%
type(x)
# Out:
# int

# %%
x
# Out:
# 30

# %%
def sums(a,b):
    result = a+b
    print( result)
    
x = sums(10,20)
type(x)
# Out:
# 30
# NoneType

# %%
# Function calling inside the another function 

def user_sum(a,b):
    print( a+b)

def calculate(x,y):
    result = user_sum(x,y)
    return result

# %%
result = calculate(10,20)
# Out:
# 30

# %%
result

# %%
type(result)
# Out:
# NoneType

# %%
def another_method(a ,b = 10):
    print(f"{a+b}, a={a},b={b}")

# %%
another_method(100,8)
# Out:
# 108, a=100,b=8

# %%
another_method(a =100)
# Out:
# 110, a=100,b=10

# %%
## find the sum of even number from 1 to 20 

def sum_even_number():
    result = 0
    for i in range(1,21):
        if i%2==0:
            result +=i
    print(result)

# %%
sum_even_number()
# Out:
# 110

# %%
def sum_even_number(a):
    if a % 2 == 0:
        return a
    return 0

total = 0

for i in range (1,51):
    result = sum_even_number(i)
    
    total+=result
    
print(total)
# Out:
# 650

# %%
## how function return a function also 

def function1(a,b):
    result = a+b
    def function2():
        result = a**b
        return result
    return function2 , result

# %%
x , y = function1(2,3)

# %%
x
# Out:
# <function __main__.function1.<locals>.function2()>

# %%
x()
# Out:
# 8

# %%
y
# Out:
# 5

# %%
x[1]
# Out:
# 5

# %%
type(x)
# Out:
# tuple

# %%
type(x[0])
# Out:
# function

# %%
type(x[1])
# Out:
# int
