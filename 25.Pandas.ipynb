# %%
import pandas as pd

# %% [markdown]
# ## What is Pandas
#
# Pandas is open-source library that is used for data manupulation and data analysis.
#
# It provide fast, flexiable and expressive data stracture.
#
# It return the data in series or dataframe that is similar to lables , relation , and tabuler data.

# %%
## create dataframe from the given dictionary

data = {
    "Name":["Amit","Rahul","Jay","Salman","Katrina","Virat"],
    "Salary":[23000, 56000, 34000,57000,56000,66000],
    "Age":[34,56,45,33,23,32]}

# %%
data
# Out:
# {'Name': ['Amit', 'Rahul', 'Jay', 'Salman', 'Katrina', 'Virat'],
#  'Salary': [23000, 56000, 34000, 57000, 56000, 66000],
#  'Age': [34, 56, 45, 33, 23, 32]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Salary  Age
# 0     Amit   23000   34
# 1    Rahul   56000   56
# 2      Jay   34000   45
# 3   Salman   57000   33
# 4  Katrina   56000   23
# 5    Virat   66000   32

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
## list to dataframe
Fruits = ["Apple","Gauva","Plam","Pomigranad","Blackberry"]
Price=[500,600,400,130,120]

# %%
fruits_data = list(zip(Fruits,Price))

# %%
fruits_data
# Out:
# [('Apple', 500),
#  ('Gauva', 600),
#  ('Plam', 400),
#  ('Pomigranad', 130),
#  ('Blackberry', 120)]

# %%
df1= pd.DataFrame(fruits_data, columns= ['Fruits','Price'])

# %%
df1
# Out:
#        Fruits  Price
# 0       Apple    500
# 1       Gauva    600
# 2        Plam    400
# 3  Pomigranad    130
# 4  Blackberry    120

# %%
## empty dataframe
df3 = pd.DataFrame()

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
df3
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df3['Fruits'] = Fruits
df3['Price']=Price

# %%
df3
# Out:
#        Fruits  Price
# 0       Apple    500
# 1       Gauva    600
# 2        Plam    400
# 3  Pomigranad    130
# 4  Blackberry    120

# %%
## function that will take n number of list to create dataframe out of that
import logging

logging.basicConfig(level=logging.INFO)

def list_to_dataframe(*lists): ## 3 list of 5 length  ### case 2 --> 3 list 5,4,5
    try:
        length_iterator = list(map(lambda x : len(x),lists)) # [5,5,5] , ##[5,4,5] -->[5,4]
        
        logging.info(f"length of each list  is length_iterator = {length_iterator}")
        
        x = set(length_iterator) # [4,4,4] --> {4}
        logging.info(f"length of x after removing the duplicate x= {x}")
        
        if len(x)!=1:
            raise ValueError("length of the given list is not same")
        else:
            data=list(zip(*lists))
            logging.info(f"here is your data after zipping{data}")
            result = pd.DataFrame(data)
        return result
    except Exception as e:
        logging.error({"type":"error", "info":str(e)})

# %%
## pass three list parameter and convert that into data frame

name= ["Rahul","Sanjeev","Sharma","Avinav"]
age = [20,24,56,45]
salary = [56000, 45000, 340000, 67000]

df4=list_to_dataframe(name,age,salary)
# Out:
# INFO:root:length of each list  is length_iterator = [4, 4, 4]
# INFO:root:length of x after removing the duplicate x= {4}
# INFO:root:here is your data after zipping[('Rahul', 20, 56000), ('Sanjeev', 24, 45000), ('Sharma', 56, 340000), ('Avinav', 45, 67000)]

# %%
df4.columns= ['name','age','Salary']

# %%
df4
# Out:
#       name  age  Salary
# 0    Rahul   20   56000
# 1  Sanjeev   24   45000
# 2   Sharma   56  340000
# 3   Avinav   45   67000

# %%
## read the data from excel

patient_file_path= r"C:\Users\prash\Desktop\Python_for_all_YT_Playlist\data\patients_data.xlsx"

patient_data = pd.read_excel(patient_file_path)

# %%
patient_data
# Out:
#      Patient_ID   Patient_Name  Age                         Email  \
# 0             1  Krishna Reddy   22  krishna.reddy835@outlook.com
# 1             2    Arjun Gupta   40    arjun.gupta570@outlook.com
# 2             3   Vivaan Singh   51      vivaan.singh72@yahoo.com
# 3             4    Arjun Kumar   36    arjun.kumar883@outlook.com
# 4             5  Krishna Verma   23    krishna.verma273@yahoo.com
# ..          ...            ...  ...                           ...
# 995         996   Vivaan Verma   32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta   67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta   27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma   49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel   72    reyansh.patel612@yahoo.com
#
#     Policy_Number Policy_Type  year
# 0       POL602544    Platinum  2025
# 1       POL856642        Gold  2025
# 2       POL512045    Platinum  2025
# ...

# %%
excel_file= pd.ExcelFile(patient_file_path)

# %%
excel_file.sheet_names
# Out:
# ['Patients_2025', 'Patients_2026']

# %%
Patients_2025_date = pd.read_excel(excel_file,sheet_name= 'Patients_2025')

# %%
Patients_2026_date = pd.read_excel(excel_file,sheet_name= 'Patients_2026')

# %%
Patients_2025_date
# Out:
#      Patient_ID   Patient_Name  Age                         Email  \
# 0             1  Krishna Reddy   22  krishna.reddy835@outlook.com
# 1             2    Arjun Gupta   40    arjun.gupta570@outlook.com
# 2             3   Vivaan Singh   51      vivaan.singh72@yahoo.com
# 3             4    Arjun Kumar   36    arjun.kumar883@outlook.com
# 4             5  Krishna Verma   23    krishna.verma273@yahoo.com
# ..          ...            ...  ...                           ...
# 995         996   Vivaan Verma   32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta   67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta   27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma   49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel   72    reyansh.patel612@yahoo.com
#
#     Policy_Number Policy_Type  year
# 0       POL602544    Platinum  2025
# 1       POL856642        Gold  2025
# 2       POL512045    Platinum  2025
# ...

# %%
Patients_2026_date
# Out:
#      Patient_ID  Patient_Name  Age                        Email Policy_Number  \
# 0          1001   Aarav Mehta   78     aarav.mehta384@yahoo.com     POL625423
# 1          1002   Aarav Verma   32     aarav.verma271@yahoo.com     POL930599
# 2          1003  Vihaan Verma   40  vihaan.verma345@outlook.com     POL456865
# 3          1004  Aditya Mehta   18  aditya.mehta579@outlook.com     POL982259
# 4          1005   Aarav Singh   39   aarav.singh126@outlook.com     POL742545
# ..          ...           ...  ...                          ...           ...
# 995        1996   Aarav Mehta   31    aarav.mehta63@outlook.com     POL748260
# 996        1997  Ishaan Yadav   59  ishaan.yadav830@outlook.com     POL725846
# 997        1998  Aarav Sharma   72     aarav.sharma12@yahoo.com     POL362369
# 998        1999  Ishaan Joshi   65   ishaan.joshi92@outlook.com     POL921223
# 999        2000  Vivaan Singh   57    vivaan.singh214@yahoo.com     POL309917
#
#     Policy_Type  Year
# ...

# %%
## read the data from the csv 

csv_file_path = r"C:\Users\prash\Desktop\Python_for_all_YT_Playlist\data\patients_data.csv"

csv_data = pd.read_csv(csv_file_path)

# %%
csv_data
# Out:
#      Patient_ID  Patient_Name  Age                        Email Policy_Number  \
# 0             1  Aditya Reddy   60  aditya.reddy437@outlook.com     POL701385
# 1             2  Aditya Verma   69  aditya.verma669@outlook.com     POL908515
# 2             3  Vivaan Reddy   58    vivaan.reddy696@yahoo.com     POL098395
# 3             4     Sai Gupta   76       sai.gupta699@gmail.com     POL802266
# 4             5  Ishaan Mehta   77  ishaan.mehta156@outlook.com     POL423233
# ..          ...           ...  ...                          ...           ...
# 995         996  Aditya Verma   41    aditya.verma839@yahoo.com     POL265181
# 996         997   Aarav Gupta   63     aarav.gupta900@gmail.com     POL797105
# 997         998  Vivaan Gupta   40    vivaan.gupta159@gmail.com     POL713191
# 998         999  Ishaan Verma   45    ishaan.verma817@gmail.com     POL146295
# 999        1000  Vihaan Patel   35    vihaan.patel222@yahoo.com     POL144496
#
#     Policy_Type
# ...

# %%
## read the data from json

json_file_path=r"C:\Users\prash\Desktop\Python_for_all_YT_Playlist\data\patients_data.json"

pd.read_json(json_file_path)
# Out:
#      Patient_ID  Patient_Name  Age                        Email Policy_Number  \
# 0             1  Aditya Reddy   60  aditya.reddy437@outlook.com     POL701385
# 1             2  Aditya Verma   69  aditya.verma669@outlook.com     POL908515
# 2             3  Vivaan Reddy   58    vivaan.reddy696@yahoo.com     POL098395
# 3             4     Sai Gupta   76       sai.gupta699@gmail.com     POL802266
# 4             5  Ishaan Mehta   77  ishaan.mehta156@outlook.com     POL423233
# ..          ...           ...  ...                          ...           ...
# 995         996  Aditya Verma   41    aditya.verma839@yahoo.com     POL265181
# 996         997   Aarav Gupta   63     aarav.gupta900@gmail.com     POL797105
# 997         998  Vivaan Gupta   40    vivaan.gupta159@gmail.com     POL713191
# 998         999  Ishaan Verma   45    ishaan.verma817@gmail.com     POL146295
# 999        1000  Vihaan Patel   35    vihaan.patel222@yahoo.com     POL144496
#
#     Policy_Type
# ...

# %% [markdown]
# 1. dict
# 2. list
# 3. Custom function to read data from n list
# 4. Excel file , sheet specific
# 5. CSV
# 6. Json

# %%
df =Patients_2025_date

# %%
df
# Out:
#      Patient_ID   Patient_Name  Age                         Email  \
# 0             1  Krishna Reddy   22  krishna.reddy835@outlook.com
# 1             2    Arjun Gupta   40    arjun.gupta570@outlook.com
# 2             3   Vivaan Singh   51      vivaan.singh72@yahoo.com
# 3             4    Arjun Kumar   36    arjun.kumar883@outlook.com
# 4             5  Krishna Verma   23    krishna.verma273@yahoo.com
# ..          ...            ...  ...                           ...
# 995         996   Vivaan Verma   32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta   67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta   27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma   49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel   72    reyansh.patel612@yahoo.com
#
#     Policy_Number Policy_Type  year
# 0       POL602544    Platinum  2025
# 1       POL856642        Gold  2025
# 2       POL512045    Platinum  2025
# ...

# %%
## how mnay rows and columns do we have

df.shape
# Out:
# (1000, 7)

# %%
df.size
# Out:
# 7000

# %%
## data types and over all view of the data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Patient_ID     1000 non-null   int64
#  1   Patient_Name   1000 non-null   object
#  2   Age            1000 non-null   int64
#  3   Email          1000 non-null   object
#  4   Policy_Number  1000 non-null   object
#  5   Policy_Type    1000 non-null   object
#  6   year           1000 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 54.8+ KB

# %%
## i want to see top 5 records
df.head()
# Out:
#    Patient_ID   Patient_Name  Age                         Email Policy_Number  \
# 0           1  Krishna Reddy   22  krishna.reddy835@outlook.com     POL602544
# 1           2    Arjun Gupta   40    arjun.gupta570@outlook.com     POL856642
# 2           3   Vivaan Singh   51      vivaan.singh72@yahoo.com     POL512045
# 3           4    Arjun Kumar   36    arjun.kumar883@outlook.com     POL132724
# 4           5  Krishna Verma   23    krishna.verma273@yahoo.com     POL060110
#
#   Policy_Type  year
# 0    Platinum  2025
# 1        Gold  2025
# 2    Platinum  2025
# 3        Gold  2025
# 4        Gold  2025

# %%
## only bottom 5 records

df.tail()
# Out:
#      Patient_ID   Patient_Name  Age                         Email  \
# 995         996   Vivaan Verma   32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta   67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta   27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma   49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel   72    reyansh.patel612@yahoo.com
#
#     Policy_Number Policy_Type  year
# 995     POL973107       Basic  2025
# 996     POL755200    Platinum  2025
# 997     POL970351     Premium  2025
# 998     POL343885     Premium  2025
# 999     POL418617     Premium  2025

# %%
## I want to see 20 records from the top

df.head(20)
# Out:
#     Patient_ID   Patient_Name  Age                         Email  \
# 0            1  Krishna Reddy   22  krishna.reddy835@outlook.com
# 1            2    Arjun Gupta   40    arjun.gupta570@outlook.com
# 2            3   Vivaan Singh   51      vivaan.singh72@yahoo.com
# 3            4    Arjun Kumar   36    arjun.kumar883@outlook.com
# 4            5  Krishna Verma   23    krishna.verma273@yahoo.com
# 5            6   Aditya Gupta   33     aditya.gupta574@yahoo.com
# 6            7   Vihaan Patel   56   vihaan.patel300@outlook.com
# 7            8   Aditya Yadav   53   aditya.yadav682@outlook.com
# 8            9      Sai Yadav   45        sai.yadav975@gmail.com
# 9           10  Aditya Sharma   23    aditya.sharma396@gmail.com
# 10          11  Reyansh Yadav   69    reyansh.yadav432@gmail.com
# 11          12   Pranav Singh   30      pranav.singh95@yahoo.com
# 12          13   Ishaan Singh   23     ishaan.singh184@gmail.com
# ...

# %%
df.tail(25)
# Out:
#      Patient_ID    Patient_Name  Age                         Email  \
# 975         976   Reyansh Patel   28   reyansh.patel62@outlook.com
# 976         977  Krishna Sharma   36   krishna.sharma255@gmail.com
# 977         978    Vivaan Yadav   44     vivaan.yadav183@gmail.com
# 978         979   Reyansh Yadav   48    reyansh.yadav654@gmail.com
# 979         980    Vihaan Gupta   29   vihaan.gupta880@outlook.com
# 980         981     Aarav Reddy   39      aarav.reddy441@gmail.com
# 981         982    Vivaan Reddy   18     vivaan.reddy710@yahoo.com
# 982         983   Reyansh Patel   20    reyansh.patel789@gmail.com
# 983         984    Aditya Reddy   56     aditya.reddy409@gmail.com
# 984         985       Sai Mehta   74       sai.mehta51@outlook.com
# 985         986    Vivaan Reddy   35   vivaan.reddy717@outlook.com
# 986         987   Krishna Singh   42   krishna.singh24@outlook.com
# 987         988   Reyansh Verma   30  reyansh.verma743@outlook.com
# ...

# %%
## I want only columns name

df.columns
# Out:
# Index(['Patient_ID', 'Patient_Name', 'Age', 'Email', 'Policy_Number',
#        'Policy_Type', 'year'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Patient_ID          Age    year
# count  1000.000000  1000.000000  1000.0
# mean    500.500000    48.075000  2025.0
# std     288.819436    18.360296     0.0
# min       1.000000    18.000000  2025.0
# 25%     250.750000    32.000000  2025.0
# 50%     500.500000    48.000000  2025.0
# 75%     750.250000    63.000000  2025.0
# max    1000.000000    80.000000  2025.0

# %%
type(df.Age)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Series:
#
#
# We have discussed about the dataframe but we have not discussed about the series
#
# ### What is series
#
# Aseries in pandas is one dimensional labeled array.
#
# It has two main part value and index(lables)

# %%
Fruits
# Out:
# ['Apple', 'Gauva', 'Plam', 'Pomigranad', 'Blackberry']

# %%
Price.append(30)

# %%
Price
# Out:
# [500, 600, 400, 130, 120, 30]

# %%
age.append(20)

# %%
age
# Out:
# [20, 24, 56, 45, 20]

# %%
name
# Out:
# ['Rahul', 'Sanjeev', 'Sharma', 'Avinav']

# %%
salary
# Out:
# [56000, 45000, 340000, 67000]

# %%
age=age[0:4]

# %%
age
# Out:
# [20, 24, 56, 45]

# %%
df
# Out:
#      Patient_ID   Patient_Name  Age                         Email  \
# 0             1  Krishna Reddy   22  krishna.reddy835@outlook.com
# 1             2    Arjun Gupta   40    arjun.gupta570@outlook.com
# 2             3   Vivaan Singh   51      vivaan.singh72@yahoo.com
# 3             4    Arjun Kumar   36    arjun.kumar883@outlook.com
# 4             5  Krishna Verma   23    krishna.verma273@yahoo.com
# ..          ...            ...  ...                           ...
# 995         996   Vivaan Verma   32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta   67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta   27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma   49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel   72    reyansh.patel612@yahoo.com
#
#     Policy_Number Policy_Type  year
# 0       POL602544    Platinum  2025
# 1       POL856642        Gold  2025
# 2       POL512045    Platinum  2025
# ...

# %%
## i want to get only one column

df.Age
# Out:
# 0      22
# 1      40
# 2      51
# 3      36
# 4      23
#        ..
# 995    32
# 996    67
# 997    27
# 998    49
# 999    72
# Name: Age, Length: 1000, dtype: int64

# %%
type(df[['Age']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['Age']
# Out:
# 0      22
# 1      40
# 2      51
# 3      36
# 4      23
#        ..
# 995    32
# 996    67
# 997    27
# 998    49
# 999    72
# Name: Age, Length: 1000, dtype: int64

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Patient_Name', 'Age', 'Email', 'Policy_Number',
#        'Policy_Type', 'year'],
#       dtype='object')

# %%
df[['Patient_Name','Age','Policy_Number']]
# Out:
#       Patient_Name  Age Policy_Number
# 0    Krishna Reddy   22     POL602544
# 1      Arjun Gupta   40     POL856642
# 2     Vivaan Singh   51     POL512045
# 3      Arjun Kumar   36     POL132724
# 4    Krishna Verma   23     POL060110
# ..             ...  ...           ...
# 995   Vivaan Verma   32     POL973107
# 996    Arjun Mehta   67     POL755200
# 997  Krishna Gupta   27     POL970351
# 998   Pranav Verma   49     POL343885
# 999  Reyansh Patel   72     POL418617
#
# [1000 rows x 3 columns]

# %%
df
# Out:
#      Patient_ID   Patient_Name  Age                         Email  \
# 0             1  Krishna Reddy   22  krishna.reddy835@outlook.com
# 1             2    Arjun Gupta   40    arjun.gupta570@outlook.com
# 2             3   Vivaan Singh   51      vivaan.singh72@yahoo.com
# 3             4    Arjun Kumar   36    arjun.kumar883@outlook.com
# 4             5  Krishna Verma   23    krishna.verma273@yahoo.com
# ..          ...            ...  ...                           ...
# 995         996   Vivaan Verma   32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta   67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta   27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma   49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel   72    reyansh.patel612@yahoo.com
#
#     Policy_Number Policy_Type  year
# 0       POL602544    Platinum  2025
# 1       POL856642        Gold  2025
# 2       POL512045    Platinum  2025
# ...

# %%
## get all the columns along with 20 to 30 rowns numbers

df.iloc[20:31,:] ## iloc -- index location 

## syntax of iloc is 

#dataframe.iloc[range_rows, range_columns]
# Out:
#     Patient_ID    Patient_Name  Age                          Email  \
# 20          21    Vihaan Kumar   73    vihaan.kumar651@outlook.com
# 21          22       Sai Verma   60       sai.verma422@outlook.com
# 22          23    Vihaan Verma   43    vihaan.verma972@outlook.com
# 23          24    Aditya Gupta   37      aditya.gupta843@yahoo.com
# 24          25    Pranav Kumar   25      pranav.kumar649@yahoo.com
# 25          26   Aditya Sharma   61     aditya.sharma1@outlook.com
# 26          27     Arjun Kumar   43     arjun.kumar396@outlook.com
# 27          28     Arjun Joshi   70       arjun.joshi601@gmail.com
# 28          29    Aditya Joshi   41      aditya.joshi111@yahoo.com
# 29          30    Vivaan Patel   44    vivaan.patel698@outlook.com
# 30          31  Reyansh Sharma   48  reyansh.sharma154@outlook.com
#
#    Policy_Number Policy_Type  year
# 20     POL996694       Basic  2025
# 21     POL752117     Premium  2025
# 22     POL926834    Platinum  2025
# ...

# %%
## get records from 15 to 25 index for column --> Patient_name , Policy_Type

df.iloc[15:26,[1,5]]
# Out:
#      Patient_Name Policy_Type
# 15   Aditya Mehta        Gold
# 16  Reyansh Joshi        Gold
# 17   Vivaan Verma     Premium
# 18   Pranav Singh       Basic
# 19      Sai Patel     Premium
# 20   Vihaan Kumar       Basic
# 21      Sai Verma     Premium
# 22   Vihaan Verma    Platinum
# 23   Aditya Gupta        Gold
# 24   Pranav Kumar    Platinum
# 25  Aditya Sharma     Premium

# %%
df.loc[15:25,['Patient_Name','Policy_Type']]

## loc ---> location 

#syntax 

#dataframe.loc[range_row, [name of the columns]]
# Out:
#      Patient_Name Policy_Type
# 15   Aditya Mehta        Gold
# 16  Reyansh Joshi        Gold
# 17   Vivaan Verma     Premium
# 18   Pranav Singh       Basic
# 19      Sai Patel     Premium
# 20   Vihaan Kumar       Basic
# 21      Sai Verma     Premium
# 22   Vihaan Verma    Platinum
# 23   Aditya Gupta        Gold
# 24   Pranav Kumar    Platinum
# 25  Aditya Sharma     Premium

# %%
df
# Out:
#      Patient_ID   Patient_Name  Age                         Email  \
# 0             1  Krishna Reddy   22  krishna.reddy835@outlook.com
# 1             2    Arjun Gupta   40    arjun.gupta570@outlook.com
# 2             3   Vivaan Singh   51      vivaan.singh72@yahoo.com
# 3             4    Arjun Kumar   36    arjun.kumar883@outlook.com
# 4             5  Krishna Verma   23    krishna.verma273@yahoo.com
# ..          ...            ...  ...                           ...
# 995         996   Vivaan Verma   32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta   67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta   27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma   49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel   72    reyansh.patel612@yahoo.com
#
#     Policy_Number Policy_Type  year
# 0       POL602544    Platinum  2025
# 1       POL856642        Gold  2025
# 2       POL512045    Platinum  2025
# ...

# %%
df.loc[45:65,['Patient_Name','Email']]
# Out:
#      Patient_Name                        Email
# 45  Vivaan Sharma   vivaan.sharma856@gmail.com
# 46  Krishna Gupta   krishna.gupta187@yahoo.com
# 47   Vihaan Patel  vihaan.patel412@outlook.com
# 48    Arjun Verma     arjun.verma648@gmail.com
# 49   Pranav Joshi  pranav.joshi515@outlook.com
# 50   Pranav Singh  pranav.singh983@outlook.com
# 51   Vivaan Reddy    vivaan.reddy408@gmail.com
# 52   Pranav Gupta    pranav.gupta629@gmail.com
# 53   Vihaan Verma    vihaan.verma629@yahoo.com
# 54   Ishaan Singh    ishaan.singh626@gmail.com
# 55   Vivaan Mehta    vivaan.mehta132@yahoo.com
# 56  Aditya Sharma   aditya.sharma908@gmail.com
# 57   Pranav Gupta  pranav.gupta267@outlook.com
# 58   Vihaan Gupta  vihaan.gupta726@outlook.com
# 59  Reyansh Singh  reyansh.singh19@outlook.com
# 60  Krishna Patel   krishna.patel524@yahoo.com
# 61   Ishaan Yadav  ishaan.yadav693@outlook.com
# 62   Arjun Sharma  arjun.sharma656@outlook.com
# 63   Vivaan Gupta     vivaan.gupta69@gmail.com
# ...

# %%
## rename the columns

df.columns
# Out:
# Index(['Patient_ID', 'Patient_Name', 'Age', 'Email', 'Policy_Number',
#        'Policy_Type', 'year'],
#       dtype='object')

# %%
df.rename(columns={'Age':'Patient_Age'}, inplace=True)

# %%
df
# Out:
#      Patient_ID   Patient_Name  Patient_Age                         Email  \
# 0             1  Krishna Reddy           22  krishna.reddy835@outlook.com
# 1             2    Arjun Gupta           40    arjun.gupta570@outlook.com
# 2             3   Vivaan Singh           51      vivaan.singh72@yahoo.com
# 3             4    Arjun Kumar           36    arjun.kumar883@outlook.com
# 4             5  Krishna Verma           23    krishna.verma273@yahoo.com
# ..          ...            ...          ...                           ...
# 995         996   Vivaan Verma           32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta           67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta           27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma           49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel           72    reyansh.patel612@yahoo.com
#
#     Policy_Number Policy_Type  year
# 0       POL602544    Platinum  2025
# ...

# %%
df.rename(columns={"Email":"Patient_Email","Policy_Number":"Policy_Num"})
# Out:
#      Patient_ID   Patient_Name  Patient_Age                 Patient_Email  \
# 0             1  Krishna Reddy           22  krishna.reddy835@outlook.com
# 1             2    Arjun Gupta           40    arjun.gupta570@outlook.com
# 2             3   Vivaan Singh           51      vivaan.singh72@yahoo.com
# 3             4    Arjun Kumar           36    arjun.kumar883@outlook.com
# 4             5  Krishna Verma           23    krishna.verma273@yahoo.com
# ..          ...            ...          ...                           ...
# 995         996   Vivaan Verma           32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta           67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta           27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma           49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel           72    reyansh.patel612@yahoo.com
#
#     Policy_Num Policy_Type  year
# 0    POL602544    Platinum  2025
# ...

# %%
df.drop(columns=['Patient_ID','year'])
# Out:
#       Patient_Name  Patient_Age                         Email Policy_Number  \
# 0    Krishna Reddy           22  krishna.reddy835@outlook.com     POL602544
# 1      Arjun Gupta           40    arjun.gupta570@outlook.com     POL856642
# 2     Vivaan Singh           51      vivaan.singh72@yahoo.com     POL512045
# 3      Arjun Kumar           36    arjun.kumar883@outlook.com     POL132724
# 4    Krishna Verma           23    krishna.verma273@yahoo.com     POL060110
# ..             ...          ...                           ...           ...
# 995   Vivaan Verma           32     vivaan.verma316@gmail.com     POL973107
# 996    Arjun Mehta           67    arjun.mehta768@outlook.com     POL755200
# 997  Krishna Gupta           27  krishna.gupta488@outlook.com     POL970351
# 998   Pranav Verma           49      pranav.verma36@yahoo.com     POL343885
# 999  Reyansh Patel           72    reyansh.patel612@yahoo.com     POL418617
#
#     Policy_Type
# 0      Platinum
# 1          Gold
# ...

# %%
df
# Out:
#      Patient_ID   Patient_Name  Patient_Age                         Email  \
# 0             1  Krishna Reddy           22  krishna.reddy835@outlook.com
# 1             2    Arjun Gupta           40    arjun.gupta570@outlook.com
# 2             3   Vivaan Singh           51      vivaan.singh72@yahoo.com
# 3             4    Arjun Kumar           36    arjun.kumar883@outlook.com
# 4             5  Krishna Verma           23    krishna.verma273@yahoo.com
# ..          ...            ...          ...                           ...
# 995         996   Vivaan Verma           32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta           67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta           27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma           49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel           72    reyansh.patel612@yahoo.com
#
#     Policy_Number Policy_Type  year
# 0       POL602544    Platinum  2025
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.set_index('Patient_ID', inplace=True)

# %%
df
# Out:
#              Patient_Name  Patient_Age                         Email  \
# Patient_ID
# 1           Krishna Reddy           22  krishna.reddy835@outlook.com
# 2             Arjun Gupta           40    arjun.gupta570@outlook.com
# 3            Vivaan Singh           51      vivaan.singh72@yahoo.com
# 4             Arjun Kumar           36    arjun.kumar883@outlook.com
# 5           Krishna Verma           23    krishna.verma273@yahoo.com
# ...                   ...          ...                           ...
# 996          Vivaan Verma           32     vivaan.verma316@gmail.com
# 997           Arjun Mehta           67    arjun.mehta768@outlook.com
# 998         Krishna Gupta           27  krishna.gupta488@outlook.com
# 999          Pranav Verma           49      pranav.verma36@yahoo.com
# 1000        Reyansh Patel           72    reyansh.patel612@yahoo.com
#
#            Policy_Number Policy_Type  year
# Patient_ID
# 1              POL602544    Platinum  2025
# ...

# %%
df.shape
# Out:
# (1000, 6)

# %%
df=df.reset_index()

# %%
df.shape
# Out:
# (1000, 7)

# %%
df.head()
# Out:
#    Patient_ID   Patient_Name  Patient_Age                         Email  \
# 0           1  Krishna Reddy           22  krishna.reddy835@outlook.com
# 1           2    Arjun Gupta           40    arjun.gupta570@outlook.com
# 2           3   Vivaan Singh           51      vivaan.singh72@yahoo.com
# 3           4    Arjun Kumar           36    arjun.kumar883@outlook.com
# 4           5  Krishna Verma           23    krishna.verma273@yahoo.com
#
#   Policy_Number Policy_Type  year
# 0     POL602544    Platinum  2025
# 1     POL856642        Gold  2025
# 2     POL512045    Platinum  2025
# 3     POL132724        Gold  2025
# 4     POL060110        Gold  2025

# %%
df.sort_values(by='Patient_Age',ascending=False,inplace=True)

# %%
df
# Out:
#      Patient_ID   Patient_Name  Patient_Age                         Email  \
# 79           80  Krishna Kumar           80    krishna.kumar274@yahoo.com
# 117         118      Sai Yadav           80        sai.yadav586@gmail.com
# 74           75      Sai Joshi           80      sai.joshi804@outlook.com
# 603         604   Pranav Patel           80     pranav.patel329@yahoo.com
# 590         591      Sai Reddy           80        sai.reddy717@yahoo.com
# ..          ...            ...          ...                           ...
# 329         330      Sai Patel           18      sai.patel488@outlook.com
# 801         802    Arjun Reddy           18    arjun.reddy613@outlook.com
# 799         800  Reyansh Yadav           18  reyansh.yadav630@outlook.com
# 263         264      Sai Patel           18        sai.patel677@gmail.com
# 479         480   Vihaan Joshi           18     vihaan.joshi116@gmail.com
#
#     Policy_Number Policy_Type  year
# 79      POL078226    Platinum  2025
# ...

# %%
## get the unique type of policy data has
df['Policy_Type'].unique()
# Out:
# array(['Platinum', 'Premium', 'Gold', 'Basic'], dtype=object)

# %%
## get the number of unique policy data has
df['Policy_Type'].nunique()
# Out:
# 4

# %%
df['Patient_Age'].unique()
# Out:
# array([80, 79, 78, 77, 76, 75, 74, 73, 72, 71, 70, 69, 68, 67, 66, 65, 64,
#        63, 62, 61, 60, 59, 58, 57, 56, 55, 54, 53, 52, 51, 50, 49, 48, 47,
#        46, 45, 44, 43, 42, 41, 40, 39, 38, 37, 36, 35, 34, 33, 32, 31, 30,
#        29, 28, 27, 26, 25, 24, 23, 22, 21, 20, 19, 18], dtype=int64)

# %%
df['Patient_Age'].nunique()
# Out:
# 63

# %%
df
# Out:
#      Patient_ID   Patient_Name  Patient_Age                         Email  \
# 79           80  Krishna Kumar           80    krishna.kumar274@yahoo.com
# 117         118      Sai Yadav           80        sai.yadav586@gmail.com
# 74           75      Sai Joshi           80      sai.joshi804@outlook.com
# 603         604   Pranav Patel           80     pranav.patel329@yahoo.com
# 590         591      Sai Reddy           80        sai.reddy717@yahoo.com
# ..          ...            ...          ...                           ...
# 329         330      Sai Patel           18      sai.patel488@outlook.com
# 801         802    Arjun Reddy           18    arjun.reddy613@outlook.com
# 799         800  Reyansh Yadav           18  reyansh.yadav630@outlook.com
# 263         264      Sai Patel           18        sai.patel677@gmail.com
# 479         480   Vihaan Joshi           18     vihaan.joshi116@gmail.com
#
#     Policy_Number Policy_Type  year
# 79      POL078226    Platinum  2025
# ...

# %%
Patients_2026_date
# Out:
#      Patient_ID  Patient_Name  Age                        Email Policy_Number  \
# 0          1001   Aarav Mehta   78     aarav.mehta384@yahoo.com     POL625423
# 1          1002   Aarav Verma   32     aarav.verma271@yahoo.com     POL930599
# 2          1003  Vihaan Verma   40  vihaan.verma345@outlook.com     POL456865
# 3          1004  Aditya Mehta   18  aditya.mehta579@outlook.com     POL982259
# 4          1005   Aarav Singh   39   aarav.singh126@outlook.com     POL742545
# ..          ...           ...  ...                          ...           ...
# 995        1996   Aarav Mehta   31    aarav.mehta63@outlook.com     POL748260
# 996        1997  Ishaan Yadav   59  ishaan.yadav830@outlook.com     POL725846
# 997        1998  Aarav Sharma   72     aarav.sharma12@yahoo.com     POL362369
# 998        1999  Ishaan Joshi   65   ishaan.joshi92@outlook.com     POL921223
# 999        2000  Vivaan Singh   57    vivaan.singh214@yahoo.com     POL309917
#
#     Policy_Type  Year
# ...

# %%
pd.concat([df,Patients_2026_date])
# Out:
#      Patient_ID   Patient_Name  Patient_Age                        Email  \
# 79           80  Krishna Kumar         80.0   krishna.kumar274@yahoo.com
# 117         118      Sai Yadav         80.0       sai.yadav586@gmail.com
# 74           75      Sai Joshi         80.0     sai.joshi804@outlook.com
# 603         604   Pranav Patel         80.0    pranav.patel329@yahoo.com
# 590         591      Sai Reddy         80.0       sai.reddy717@yahoo.com
# ..          ...            ...          ...                          ...
# 995        1996    Aarav Mehta          NaN    aarav.mehta63@outlook.com
# 996        1997   Ishaan Yadav          NaN  ishaan.yadav830@outlook.com
# 997        1998   Aarav Sharma          NaN     aarav.sharma12@yahoo.com
# 998        1999   Ishaan Joshi          NaN   ishaan.joshi92@outlook.com
# 999        2000   Vivaan Singh          NaN    vivaan.singh214@yahoo.com
#
#     Policy_Number Policy_Type    year   Age    Year
# ...

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Patient_Name', 'Patient_Age', 'Email', 'Policy_Number',
#        'Policy_Type', 'year'],
#       dtype='object')

# %%
Patients_2026_date.columns
# Out:
# Index(['Patient_ID', 'Patient_Name', 'Age', 'Email', 'Policy_Number',
#        'Policy_Type', 'Year'],
#       dtype='object')

# %%
Patients_2026_date.rename(columns={'Age':'Patient_Age','Year':'year'}, inplace=True)

# %%
Patients_2026_date.columns
# Out:
# Index(['Patient_ID', 'Patient_Name', 'Patient_Age', 'Email', 'Policy_Number',
#        'Policy_Type', 'year'],
#       dtype='object')

# %%
patient_data=pd.concat([df,Patients_2026_date],axis=0)

# %%
patient_data.shape
# Out:
# (2000, 7)

# %%
patient_data.reset_index(inplace=True)

# %%
patient_data.head()
# Out:
#    index  Patient_ID   Patient_Name  Patient_Age                       Email  \
# 0     79          80  Krishna Kumar           80  krishna.kumar274@yahoo.com
# 1    117         118      Sai Yadav           80      sai.yadav586@gmail.com
# 2     74          75      Sai Joshi           80    sai.joshi804@outlook.com
# 3    603         604   Pranav Patel           80   pranav.patel329@yahoo.com
# 4    590         591      Sai Reddy           80      sai.reddy717@yahoo.com
#
#   Policy_Number Policy_Type  year
# 0     POL078226    Platinum  2025
# 1     POL034543    Platinum  2025
# 2     POL875971     Premium  2025
# 3     POL097005     Premium  2025
# 4     POL640591     Premium  2025

# %%
## drop the column index

patient_data.drop(columns='index', inplace=True)

# %%
patient_data.head()
# Out:
#    Patient_ID   Patient_Name  Patient_Age                       Email  \
# 0          80  Krishna Kumar           80  krishna.kumar274@yahoo.com
# 1         118      Sai Yadav           80      sai.yadav586@gmail.com
# 2          75      Sai Joshi           80    sai.joshi804@outlook.com
# 3         604   Pranav Patel           80   pranav.patel329@yahoo.com
# 4         591      Sai Reddy           80      sai.reddy717@yahoo.com
#
#   Policy_Number Policy_Type  year
# 0     POL078226    Platinum  2025
# 1     POL034543    Platinum  2025
# 2     POL875971     Premium  2025
# 3     POL097005     Premium  2025
# 4     POL640591     Premium  2025

# %%
policy_file_path = r"C:\Users\prash\Desktop\Python_for_all_YT_Playlist\data\policy_data.xlsx"

# %%
policy_data= pd.read_excel(policy_file_path)

# %%
policy_data.shape
# Out:
# (2000, 4)

# %%
policy_data
# Out:
#      Policy_Number        Provider_Name  Coverage_Amount  Start_Year
# 0        POL602544  New India Assurance           586130        2025
# 1        POL856642             Max Bupa           216864        2024
# 2        POL512045  New India Assurance           218977        2025
# 3        POL132724             Max Bupa           842430        2025
# 4        POL060110          Star Health           806879        2025
# ...            ...                  ...              ...         ...
# 1995     POL748260          Star Health           484092        2024
# 1996     POL725846          Star Health           579515        2023
# 1997     POL362369             Max Bupa           644437        2023
# 1998     POL921223             Max Bupa           965221        2024
# 1999     POL309917        ICICI Lombard           213392        2024
#
# [2000 rows x 4 columns]

# %%
##pd.concat([patient_data,policy_data],axis=1)# you can't use cancatination on relational data. beciase cancat perform based on index match

# %%
## Merge

patient_data.merge(policy_data,how='left',on='Policy_Number')
# Out:
#       Patient_ID   Patient_Name  Patient_Age                        Email  \
# 0             80  Krishna Kumar           80   krishna.kumar274@yahoo.com
# 1            118      Sai Yadav           80       sai.yadav586@gmail.com
# 2             75      Sai Joshi           80     sai.joshi804@outlook.com
# 3            604   Pranav Patel           80    pranav.patel329@yahoo.com
# 4            591      Sai Reddy           80       sai.reddy717@yahoo.com
# ...          ...            ...          ...                          ...
# 1997        1996    Aarav Mehta           31    aarav.mehta63@outlook.com
# 1998        1997   Ishaan Yadav           59  ishaan.yadav830@outlook.com
# 1999        1998   Aarav Sharma           72     aarav.sharma12@yahoo.com
# 2000        1999   Ishaan Joshi           65   ishaan.joshi92@outlook.com
# 2001        2000   Vivaan Singh           57    vivaan.singh214@yahoo.com
#
#      Policy_Number Policy_Type  year  Provider_Name  Coverage_Amount  \
# ...

# %%
## case 2 -- if both the data fame common columns name is not same, what ypu will do in this case?

# %%
policy_data.rename(columns ={'Policy_Number':'policy_number'},inplace=True)

# %%
policy_data.head()
# Out:
#   policy_number        Provider_Name  Coverage_Amount  Start_Year
# 0     POL602544  New India Assurance           586130        2025
# 1     POL856642             Max Bupa           216864        2024
# 2     POL512045  New India Assurance           218977        2025
# 3     POL132724             Max Bupa           842430        2025
# 4     POL060110          Star Health           806879        2025

# %%
patient_data=patient_data.merge(policy_data,how='left',left_on='Policy_Number',right_on='policy_number')

# %%
patient_data
# Out:
#       Patient_ID   Patient_Name  Patient_Age                        Email  \
# 0             80  Krishna Kumar           80   krishna.kumar274@yahoo.com
# 1            118      Sai Yadav           80       sai.yadav586@gmail.com
# 2             75      Sai Joshi           80     sai.joshi804@outlook.com
# 3            604   Pranav Patel           80    pranav.patel329@yahoo.com
# 4            591      Sai Reddy           80       sai.reddy717@yahoo.com
# ...          ...            ...          ...                          ...
# 1997        1996    Aarav Mehta           31    aarav.mehta63@outlook.com
# 1998        1997   Ishaan Yadav           59  ishaan.yadav830@outlook.com
# 1999        1998   Aarav Sharma           72     aarav.sharma12@yahoo.com
# 2000        1999   Ishaan Joshi           65   ishaan.joshi92@outlook.com
# 2001        2000   Vivaan Singh           57    vivaan.singh214@yahoo.com
#
#      Policy_Number Policy_Type  year policy_number  Provider_Name  \
# ...

# %%
patient_data.drop(columns={'policy_number'}, inplace=True)

# %%
patient_data.head()
# Out:
#    Patient_ID   Patient_Name  Patient_Age                       Email  \
# 0          80  Krishna Kumar           80  krishna.kumar274@yahoo.com
# 1         118      Sai Yadav           80      sai.yadav586@gmail.com
# 2          75      Sai Joshi           80    sai.joshi804@outlook.com
# 3         604   Pranav Patel           80   pranav.patel329@yahoo.com
# 4         591      Sai Reddy           80      sai.reddy717@yahoo.com
#
#   Policy_Number Policy_Type  year Provider_Name  Coverage_Amount  Start_Year
# 0     POL078226    Platinum  2025     HDFC Ergo           851420        2026
# 1     POL034543    Platinum  2025   Star Health           829205        2023
# 2     POL875971     Premium  2025   Star Health           659481        2025
# 3     POL097005     Premium  2025     HDFC Ergo           135569        2026
# 4     POL640591     Premium  2025     HDFC Ergo           954316        2026

# %%
patient_data.shape
# Out:
# (2002, 10)

# %%
## filter out patient data where policy type is basic

patient_data[patient_data["Policy_Type"]=="Basic"]
# Out:
#       Patient_ID   Patient_Name  Patient_Age                         Email  \
# 17           340   Ishaan Kumar           79   ishaan.kumar451@outlook.com
# 23           388    Arjun Reddy           79      arjun.reddy866@yahoo.com
# 25           295   Ishaan Gupta           79   ishaan.gupta980@outlook.com
# 30           384    Aarav Singh           78      aarav.singh557@yahoo.com
# 31           173  Krishna Yadav           78  krishna.yadav117@outlook.com
# ...          ...            ...          ...                           ...
# 1978        1977   Vivaan Singh           43     vivaan.singh140@gmail.com
# 1979        1978   Vivaan Patel           56     vivaan.patel152@gmail.com
# 1994        1993   Pranav Mehta           66     pranav.mehta382@yahoo.com
# 1996        1995  Reyansh Joshi           52    reyansh.joshi728@gmail.com
# 1998        1997   Ishaan Yadav           59   ishaan.yadav830@outlook.com
#
# ...

# %%
## how many patient above 40 has taken policy from ICICI Lombard
patient_data[(patient_data['Patient_Age']>40) & (patient_data['Provider_Name']=='ICICI Lombard')  ].count()
# Out:
# Patient_ID         270
# Patient_Name       270
# Patient_Age        270
# Email              270
# Policy_Number      270
# Policy_Type        270
# year               270
# Provider_Name      270
# Coverage_Amount    270
# Start_Year         270
# dtype: int64

# %%
## how many patient above age 50 taken insurence from Icici or HDFC

patient_data[(patient_data['Patient_Age']>50) & 
             ((patient_data['Provider_Name']=='ICICI Lombard') | 
              (patient_data['Provider_Name']=='HDFC Ergo'))  ].count()
# Out:
# Patient_ID         379
# Patient_Name       379
# Patient_Age        379
# Email              379
# Policy_Number      379
# Policy_Type        379
# year               379
# Provider_Name      379
# Coverage_Amount    379
# Start_Year         379
# dtype: int64

# %%
## how many patient has invested amount b/w 200000 to 400000 during year 2023 and 2024 in insurence
    
patient_data[(patient_data['Coverage_Amount'].between(200000, 400000)) & (patient_data['Start_Year'].isin([2023,2024]))]['Patient_ID'].count()
# Out:
# 248

# %%
## how to find there is duplicate in the data or not 

patient_data['Patient_ID'].value_counts()
# Out:
# Patient_ID
# 1173    2
# 1581    2
# 1330    1
# 1342    1
# 1341    1
#        ..
# 24      1
# 353     1
# 176     1
# 895     1
# 2000    1
# Name: count, Length: 2000, dtype: int64

# %%
patient_data[patient_data['Patient_ID'].isin([1173,1581])]
# Out:
#       Patient_ID   Patient_Name  Patient_Age                         Email  \
# 1172        1173  Krishna Mehta           59  krishna.mehta687@outlook.com
# 1173        1173  Krishna Mehta           59  krishna.mehta687@outlook.com
# 1581        1581   Aditya Patel           31     aditya.patel676@yahoo.com
# 1582        1581   Aditya Patel           31     aditya.patel676@yahoo.com
#
#      Policy_Number Policy_Type  year Provider_Name  Coverage_Amount  \
# 1172     POL071964     Premium  2026     HDFC Ergo           169951
# 1173     POL071964     Premium  2026      Max Bupa           718566
# 1581     POL071964     Premium  2026     HDFC Ergo           169951
# 1582     POL071964     Premium  2026      Max Bupa           718566
#
#       Start_Year
# 1172        2023
# 1173        2025
# 1581        2023
# 1582        2025

# %%
patient_data.drop_duplicates(subset='Patient_ID',keep='first', inplace=True)

# %%
patient_data['Patient_ID'].duplicated().sum()
# Out:
# 0

# %%
patient_data['Coverage_Amount'].unique()
# Out:
# array([851420, 829205, 659481, ..., 644437, 965221, 213392], dtype=int64)

# %%
## how many patient has invested amount b/w 200000 to 400000 during year 2023 and 2024 in insurence
    
patient_data[(patient_data['Coverage_Amount'].between(200000, 400000)) & (patient_data['Start_Year'].isin([2023,2024]))]['Patient_ID'].count()
# Out:
# 248

# %%
patient_data.head()
# Out:
#    Patient_ID   Patient_Name  Patient_Age                       Email  \
# 0          80  Krishna Kumar           80  krishna.kumar274@yahoo.com
# 1         118      Sai Yadav           80      sai.yadav586@gmail.com
# 2          75      Sai Joshi           80    sai.joshi804@outlook.com
# 3         604   Pranav Patel           80   pranav.patel329@yahoo.com
# 4         591      Sai Reddy           80      sai.reddy717@yahoo.com
#
#   Policy_Number Policy_Type  year Provider_Name  Coverage_Amount  Start_Year
# 0     POL078226    Platinum  2025     HDFC Ergo           851420        2026
# 1     POL034543    Platinum  2025   Star Health           829205        2023
# 2     POL875971     Premium  2025   Star Health           659481        2025
# 3     POL097005     Premium  2025     HDFC Ergo           135569        2026
# 4     POL640591     Premium  2025     HDFC Ergo           954316        2026

# %%
patient_data.query("Coverage_Amount.between(200000,400000) and Start_Year.isin([2023,2024])")
# Out:
#       Patient_ID   Patient_Name  Patient_Age                         Email  \
# 12           471   Aditya Reddy           80   aditya.reddy246@outlook.com
# 16           147   Aditya Kumar           79     aditya.kumar636@gmail.com
# 17           340   Ishaan Kumar           79   ishaan.kumar451@outlook.com
# 18           218   Vivaan Gupta           79   vivaan.gupta585@outlook.com
# 20           635    Aarav Gupta           79    aarav.gupta587@outlook.com
# ...          ...            ...          ...                           ...
# 1958        1957   Pranav Gupta           60     pranav.gupta933@yahoo.com
# 1959        1958   Vihaan Patel           39     vihaan.patel448@yahoo.com
# 1960        1959  Reyansh Gupta           74  reyansh.gupta307@outlook.com
# 1993        1992    Aarav Singh           71      aarav.singh994@gmail.com
# 2001        2000   Vivaan Singh           57     vivaan.singh214@yahoo.com
#
# ...

# %%
## filter out patient details whos age is grater than 40 and taken Premium policy

patient_data.query("Patient_Age>40 and Policy_Type == 'Premium'" )
# Out:
#       Patient_ID   Patient_Name  Patient_Age                       Email  \
# 2             75      Sai Joshi           80    sai.joshi804@outlook.com
# 3            604   Pranav Patel           80   pranav.patel329@yahoo.com
# 4            591      Sai Reddy           80      sai.reddy717@yahoo.com
# 7             71     Sai Sharma           80     sai.sharma866@yahoo.com
# 8            808   Ishaan Verma           80   ishaan.verma174@yahoo.com
# ...          ...            ...          ...                         ...
# 1980        1979      Sai Singh           60    sai.singh449@outlook.com
# 1982        1981      Sai Verma           79      sai.verma933@gmail.com
# 1986        1985   Vihaan Mehta           80    vihaan.mehta18@yahoo.com
# 1991        1990  Krishna Yadav           49  krishna.yadav340@yahoo.com
# 2000        1999   Ishaan Joshi           65  ishaan.joshi92@outlook.com
#
#      Policy_Number Policy_Type  year Provider_Name  Coverage_Amount  \
# ...

# %%
## how many patient email id contains gmail.com

patient_data[patient_data["Email"].str.contains('gmail.com')]['Patient_ID'].count()
# Out:
# 632

# %%
## how many patients email start with AR
patient_data[patient_data["Email"].str.startswith('ar')]
# Out:
#       Patient_ID  Patient_Name  Patient_Age                        Email  \
# 23           388   Arjun Reddy           79     arjun.reddy866@yahoo.com
# 32           568   Arjun Singh           78     arjun.singh955@gmail.com
# 47           823  Arjun Sharma           77  arjun.sharma553@outlook.com
# 65           815   Arjun Yadav           76     arjun.yadav841@yahoo.com
# 74           766   Arjun Joshi           76     arjun.joshi809@yahoo.com
# ...          ...           ...          ...                          ...
# 1936        1935   Arjun Joshi           41     arjun.joshi408@gmail.com
# 1939        1938   Arjun Patel           51     arjun.patel163@yahoo.com
# 1940        1939   Arjun Yadav           55     arjun.yadav996@yahoo.com
# 1963        1962   Arjun Singh           76      arjun.singh26@gmail.com
# 1992        1991   Arjun Mehta           77     arjun.mehta725@yahoo.com
#
#      Policy_Number Policy_Type  year        Provider_Name  Coverage_Amount  \
# ...

# %%
patient_data[patient_data["Email"].str.startswith('ar')]['Patient_ID'].count()
# Out:
# 190

# %%
## how many patient last name end with Singh
patient_data[patient_data["Patient_Name"].str.endswith('Singh')]
# Out:
#       Patient_ID  Patient_Name  Patient_Age                        Email  \
# 5            825  Aditya Singh           80  aditya.singh435@outlook.com
# 27            99  Aditya Singh           79    aditya.singh601@yahoo.com
# 29           502  Vihaan Singh           79    vihaan.singh558@gmail.com
# 30           384   Aarav Singh           78     aarav.singh557@yahoo.com
# 32           568   Arjun Singh           78     arjun.singh955@gmail.com
# ...          ...           ...          ...                          ...
# 1978        1977  Vivaan Singh           43    vivaan.singh140@gmail.com
# 1980        1979     Sai Singh           60     sai.singh449@outlook.com
# 1988        1987  Aditya Singh           26    aditya.singh106@yahoo.com
# 1993        1992   Aarav Singh           71     aarav.singh994@gmail.com
# 2001        2000  Vivaan Singh           57    vivaan.singh214@yahoo.com
#
#      Policy_Number Policy_Type  year        Provider_Name  Coverage_Amount  \
# ...

# %%
patient_data[patient_data["Patient_Name"].str.endswith('Singh')]['Patient_ID'].count()
# Out:
# 227

# %% [markdown]
# where
# mask
# cut
# notnull()
# dropna()
# fillna()
# Apply()
# Map()
# Split columns
# strip , lower , upper
# Group by
# Multiple columns group by
# agg function
# pivot()
# Pivot_tables
# stack()
# unstack()
# crosstab()
# Rank()
# Rolling window()
# Resampling()

# %%
patient_data
# Out:
#       Patient_ID   Patient_Name  Patient_Age                        Email  \
# 0             80  Krishna Kumar           80   krishna.kumar274@yahoo.com
# 1            118      Sai Yadav           80       sai.yadav586@gmail.com
# 2             75      Sai Joshi           80     sai.joshi804@outlook.com
# 3            604   Pranav Patel           80    pranav.patel329@yahoo.com
# 4            591      Sai Reddy           80       sai.reddy717@yahoo.com
# ...          ...            ...          ...                          ...
# 1997        1996    Aarav Mehta           31    aarav.mehta63@outlook.com
# 1998        1997   Ishaan Yadav           59  ishaan.yadav830@outlook.com
# 1999        1998   Aarav Sharma           72     aarav.sharma12@yahoo.com
# 2000        1999   Ishaan Joshi           65   ishaan.joshi92@outlook.com
# 2001        2000   Vivaan Singh           57    vivaan.singh214@yahoo.com
#
#      Policy_Number Policy_Type  year  Provider_Name  Coverage_Amount  \
# ...

# %%
patient_data["Patient_Age"].unique()
# Out:
# array([80, 79, 78, 77, 76, 75, 74, 73, 72, 71, 70, 69, 68, 67, 66, 65, 64,
#        63, 62, 61, 60, 59, 58, 57, 56, 55, 54, 53, 52, 51, 50, 49, 48, 47,
#        46, 45, 44, 43, 42, 41, 40, 39, 38, 37, 36, 35, 34, 33, 32, 31, 30,
#        29, 28, 27, 26, 25, 24, 23, 22, 21, 20, 19, 18], dtype=int64)

# %% [markdown]
# ## Where
# 1.It is used to replace the value where a condition is false
# 2. Keep the value if condition is True, otherwise replace it.
#
# syntax
#
# df.where(condition,other)
#
# where(condition, value_if_false)

# %%
patient_data['Patient_Age_category']=patient_data['Patient_Age'].where(patient_data['Patient_Age']>30 , "Young")

# %%
patient_data.sort_values(by='Patient_Age',ascending=True)
# Out:
#       Patient_ID   Patient_Name  Patient_Age                         Email  \
# 999          480   Vihaan Joshi           18     vihaan.joshi116@gmail.com
# 983          641  Reyansh Verma           18  reyansh.verma874@outlook.com
# 982           79  Reyansh Gupta           18  reyansh.gupta705@outlook.com
# 1942        1941      Sai Gupta           18      sai.gupta133@outlook.com
# 1387        1387   Vihaan Gupta           18   vihaan.gupta357@outlook.com
# ...          ...            ...          ...                           ...
# 9            799   Aditya Gupta           80   aditya.gupta892@outlook.com
# 1505        1505    Aarav Patel           80      aarav.patel737@yahoo.com
# 8            808   Ishaan Verma           80     ishaan.verma174@yahoo.com
# 1375        1375    Arjun Verma           80    arjun.verma443@outlook.com
# 0             80  Krishna Kumar           80    krishna.kumar274@yahoo.com
#
# ...

# %%
patient_data[patient_data['Patient_Age'].isin([18,25,29,31,30,45])]
# Out:
#       Patient_ID   Patient_Name  Patient_Age                         Email  \
# 536          326   Aditya Mehta           45     aditya.mehta365@gmail.com
# 537          659    Aarav Yadav           45    aarav.yadav297@outlook.com
# 538            9      Sai Yadav           45        sai.yadav975@gmail.com
# 539          307      Sai Gupta           45      sai.gupta389@outlook.com
# 540          593  Reyansh Gupta           45  reyansh.gupta163@outlook.com
# ...          ...            ...          ...                           ...
# 1942        1941      Sai Gupta           18      sai.gupta133@outlook.com
# 1949        1948   Pranav Joshi           25     pranav.joshi820@yahoo.com
# 1954        1953   Aditya Joshi           31   aditya.joshi357@outlook.com
# 1975        1974   Pranav Gupta           45   pranav.gupta188@outlook.com
# 1997        1996    Aarav Mehta           31     aarav.mehta63@outlook.com
#
# ...

# %% [markdown]
# ## now
# I want to map
#
# age description
#
# 0 to 29 ---> Young
# 30 to 49 ---> Middle Age
# 50 to 60 ---> Early Older
#
# >> 60 ----> Older Age

# %%
patient_data['Patient_Age_category']=patient_data['Patient_Age'].where(patient_data['Patient_Age']>30 , "Young").where((patient_data['Patient_Age']>50) |(patient_data['Patient_Age']<30),'Middle Age').where((patient_data['Patient_Age']>60) | (patient_data['Patient_Age']<50),'Early Older').where(patient_data['Patient_Age']<60,"Older Age")

# %%
patient_data[patient_data['Patient_Age'].isin([25,26])]
# Out:
#       Patient_ID   Patient_Name  Patient_Age                        Email  \
# 836          356    Arjun Patel           26     arjun.patel474@gmail.com
# 837          355   Vivaan Patel           26  vivaan.patel766@outlook.com
# 838          548  Krishna Patel           26   krishna.patel358@yahoo.com
# 839          681   Aditya Patel           26    aditya.patel268@gmail.com
# 840          566    Aarav Yadav           26   aarav.yadav345@outlook.com
# ...          ...            ...          ...                          ...
# 1730        1729  Krishna Reddy           26   krishna.reddy309@yahoo.com
# 1824        1823   Pranav Patel           26     pranav.patel13@yahoo.com
# 1891        1890      Sai Singh           26       sai.singh263@yahoo.com
# 1949        1948   Pranav Joshi           25    pranav.joshi820@yahoo.com
# 1988        1987   Aditya Singh           26    aditya.singh106@yahoo.com
#
#      Policy_Number Policy_Type  year        Provider_Name  Coverage_Amount  \
# ...

# %%
patient_data['Patient_Age_category'].unique()
# Out:
# array(['Older Age', 'Early Older', 'Middle Age', 'Young'], dtype=object)

# %%
patient_data['Provider_Name']=patient_data['Provider_Name'].where(patient_data['Provider_Name']!='New India Assurance',"India Insurance")

# %%
patient_data['Provider_Name'].unique()
# Out:
# array(['HDFC Ergo', 'Star Health', 'ICICI Lombard', 'Max Bupa',
#        'India Insurance'], dtype=object)

# %%
## Mask

#it will chnage the value whenever the condition is True

# %% [markdown]
# ## now
# I want to map
#
# age description
#
# 0 to 29 ---> Young
# 30 to 49 ---> Middle Age
# 50 to 60 ---> Early Older
#
# >> 60 ----> Older Age

# %%
patient_data['Mask_Age_example']= patient_data['Patient_Age'].mask(patient_data['Patient_Age']<30,"Young").mask((patient_data['Patient_Age']>=30)&(patient_data['Patient_Age']<50 ),'Middle Age').mask((patient_data['Patient_Age']>=50)&(patient_data['Patient_Age']<=60 ),"Early Older").mask(patient_data['Patient_Age']>60,'Older Age')

# %%
patient_data
# Out:
#       Patient_ID   Patient_Name  Patient_Age                        Email  \
# 0             80  Krishna Kumar           80   krishna.kumar274@yahoo.com
# 1            118      Sai Yadav           80       sai.yadav586@gmail.com
# 2             75      Sai Joshi           80     sai.joshi804@outlook.com
# 3            604   Pranav Patel           80    pranav.patel329@yahoo.com
# 4            591      Sai Reddy           80       sai.reddy717@yahoo.com
# ...          ...            ...          ...                          ...
# 1997        1996    Aarav Mehta           31    aarav.mehta63@outlook.com
# 1998        1997   Ishaan Yadav           59  ishaan.yadav830@outlook.com
# 1999        1998   Aarav Sharma           72     aarav.sharma12@yahoo.com
# 2000        1999   Ishaan Joshi           65   ishaan.joshi92@outlook.com
# 2001        2000   Vivaan Singh           57    vivaan.singh214@yahoo.com
#
#      Policy_Number Policy_Type  year  Provider_Name  Coverage_Amount  \
# ...

# %%
bins = [0, 30, 50, 60, 100]
labels = ["Young", "Middle Age", "Early Older", "Senior"]

patient_data["Age_remark"] = pd.cut(patient_data["Patient_Age"] , bins=bins, labels=labels, right=True)

# %%
patient_data
# Out:
#       Patient_ID   Patient_Name  Patient_Age                        Email  \
# 0             80  Krishna Kumar           80   krishna.kumar274@yahoo.com
# 1            118      Sai Yadav           80       sai.yadav586@gmail.com
# 2             75      Sai Joshi           80     sai.joshi804@outlook.com
# 3            604   Pranav Patel           80    pranav.patel329@yahoo.com
# 4            591      Sai Reddy           80       sai.reddy717@yahoo.com
# ...          ...            ...          ...                          ...
# 1997        1996    Aarav Mehta           31    aarav.mehta63@outlook.com
# 1998        1997   Ishaan Yadav           59  ishaan.yadav830@outlook.com
# 1999        1998   Aarav Sharma           72     aarav.sharma12@yahoo.com
# 2000        1999   Ishaan Joshi           65   ishaan.joshi92@outlook.com
# 2001        2000   Vivaan Singh           57    vivaan.singh214@yahoo.com
#
#      Policy_Number Policy_Type  year  Provider_Name  Coverage_Amount  \
# ...

# %% [markdown]
# isna()
# isnull()
#
# to identify the null values in the dataframe

# %%
patient_data.isna().sum()
# Out:
# Patient_ID              0
# Patient_Name            0
# Patient_Age             0
# Email                   0
# Policy_Number           0
# Policy_Type             0
# year                    0
# Provider_Name           0
# Coverage_Amount         0
# Start_Year              0
# Patient_Age_category    0
# Mask_Age_example        0
# Age_remark              0
# dtype: int64

# %%
patient_data.isnull().sum()
# Out:
# Patient_ID              0
# Patient_Name            0
# Patient_Age             0
# Email                   0
# Policy_Number           0
# Policy_Type             0
# year                    0
# Provider_Name           0
# Coverage_Amount         0
# Start_Year              0
# Patient_Age_category    0
# Mask_Age_example        0
# Age_remark              0
# dtype: int64

# %%
## create null value in age 

patient_data["Patient_Age"]=patient_data["Patient_Age"].mask(patient_data["Patient_Age"]>60,None)

# %%
patient_data.isnull().sum()
# Out:
# Patient_ID                0
# Patient_Name              0
# Patient_Age             646
# Email                     0
# Policy_Number             0
# Policy_Type               0
# year                      0
# Provider_Name             0
# Coverage_Amount           0
# Start_Year                0
# Patient_Age_category      0
# Mask_Age_example          0
# Age_remark                0
# dtype: int64

# %%
patient_data.notnull().sum()
# Out:
# Patient_ID              2000
# Patient_Name            2000
# Patient_Age             1354
# Email                   2000
# Policy_Number           2000
# Policy_Type             2000
# year                    2000
# Provider_Name           2000
# Coverage_Amount         2000
# Start_Year              2000
# Patient_Age_category    2000
# Mask_Age_example        2000
# Age_remark              2000
# dtype: int64

# %%
patient_data["Patient_Age"]=patient_data["Patient_Age"].fillna(77)

# %%
patient_data.isnull().sum()
# Out:
# Patient_ID              0
# Patient_Name            0
# Patient_Age             0
# Email                   0
# Policy_Number           0
# Policy_Type             0
# year                    0
# Provider_Name           0
# Coverage_Amount         0
# Start_Year              0
# Patient_Age_category    0
# Mask_Age_example        0
# Age_remark              0
# dtype: int64

# %% [markdown]
# ## Apply()
# Apply function used in the pandas dataframe or series to apply custom function on the row, columns , individual data .
#
# when pandas in-build function is not enough and you want to apply custom function over column, row etc in such case we use Apply

# %%
patient_data
# Out:
#       Patient_ID   Patient_Name  Patient_Age                        Email  \
# 0             80  Krishna Kumar         77.0   krishna.kumar274@yahoo.com
# 1            118      Sai Yadav         77.0       sai.yadav586@gmail.com
# 2             75      Sai Joshi         77.0     sai.joshi804@outlook.com
# 3            604   Pranav Patel         77.0    pranav.patel329@yahoo.com
# 4            591      Sai Reddy         77.0       sai.reddy717@yahoo.com
# ...          ...            ...          ...                          ...
# 1997        1996    Aarav Mehta         31.0    aarav.mehta63@outlook.com
# 1998        1997   Ishaan Yadav         59.0  ishaan.yadav830@outlook.com
# 1999        1998   Aarav Sharma         77.0     aarav.sharma12@yahoo.com
# 2000        1999   Ishaan Joshi         77.0   ishaan.joshi92@outlook.com
# 2001        2000   Vivaan Singh         57.0    vivaan.singh214@yahoo.com
#
#      Policy_Number Policy_Type  year  Provider_Name  Coverage_Amount  \
# ...

# %%
patient_data['Email_domain']=patient_data['Email'].apply(lambda x : x.split('@')[1])

# %%
patient_data
# Out:
#       Patient_ID   Patient_Name  Patient_Age                        Email  \
# 0             80  Krishna Kumar         77.0   krishna.kumar274@yahoo.com
# 1            118      Sai Yadav         77.0       sai.yadav586@gmail.com
# 2             75      Sai Joshi         77.0     sai.joshi804@outlook.com
# 3            604   Pranav Patel         77.0    pranav.patel329@yahoo.com
# 4            591      Sai Reddy         77.0       sai.reddy717@yahoo.com
# ...          ...            ...          ...                          ...
# 1997        1996    Aarav Mehta         31.0    aarav.mehta63@outlook.com
# 1998        1997   Ishaan Yadav         59.0  ishaan.yadav830@outlook.com
# 1999        1998   Aarav Sharma         77.0     aarav.sharma12@yahoo.com
# 2000        1999   Ishaan Joshi         77.0   ishaan.joshi92@outlook.com
# 2001        2000   Vivaan Singh         57.0    vivaan.singh214@yahoo.com
#
#      Policy_Number Policy_Type  year  Provider_Name  Coverage_Amount  \
# ...

# %% [markdown]
# risk_factor
#
# if age>50 and Policy type == "Basic"  ==> High risk
# if age>50 and Policy type =="Gold" ==>  Normal risk
# if age>50 and Policy type == "Platinum" ==> Normal

# %%
def risk_factor(row):
    if row["Patient_Age"] >= 50 and row["Policy_Type"] == "Basic":
        return "High Risk"
    elif row['Patient_Age']>=50 and row["Policy_Type"]=="Gold":
        return "Normal Risk"
    elif row['Patient_Age']>=50 and row['Policy_Type'] =='Platinum':
        return "Normal"
    else:
        return "Age is below 50"

# %%
patient_data
# Out:
#       Patient_ID   Patient_Name  Patient_Age                        Email  \
# 0             80  Krishna Kumar         77.0   krishna.kumar274@yahoo.com
# 1            118      Sai Yadav         77.0       sai.yadav586@gmail.com
# 2             75      Sai Joshi         77.0     sai.joshi804@outlook.com
# 3            604   Pranav Patel         77.0    pranav.patel329@yahoo.com
# 4            591      Sai Reddy         77.0       sai.reddy717@yahoo.com
# ...          ...            ...          ...                          ...
# 1997        1996    Aarav Mehta         31.0    aarav.mehta63@outlook.com
# 1998        1997   Ishaan Yadav         59.0  ishaan.yadav830@outlook.com
# 1999        1998   Aarav Sharma         77.0     aarav.sharma12@yahoo.com
# 2000        1999   Ishaan Joshi         77.0   ishaan.joshi92@outlook.com
# 2001        2000   Vivaan Singh         57.0    vivaan.singh214@yahoo.com
#
#      Policy_Number Policy_Type  year  Provider_Name  Coverage_Amount  \
# ...

# %%
patient_data['Patient_Age']=patient_data['Patient_Age'].astype(int)

# %%
patient_data.columns
# Out:
# Index(['Patient_ID', 'Patient_Name', 'Patient_Age', 'Email', 'Policy_Number',
#        'Policy_Type', 'year', 'Provider_Name', 'Coverage_Amount', 'Start_Year',
#        'Patient_Age_category', 'Mask_Age_example', 'Age_remark',
#        'Email_domain'],
#       dtype='object')

# %%
patient_data['risk_factor'] = patient_data.apply(risk_factor,axis=1)

# %%
patient_data
# Out:
#       Patient_ID   Patient_Name  Patient_Age                        Email  \
# 0             80  Krishna Kumar           77   krishna.kumar274@yahoo.com
# 1            118      Sai Yadav           77       sai.yadav586@gmail.com
# 2             75      Sai Joshi           77     sai.joshi804@outlook.com
# 3            604   Pranav Patel           77    pranav.patel329@yahoo.com
# 4            591      Sai Reddy           77       sai.reddy717@yahoo.com
# ...          ...            ...          ...                          ...
# 1997        1996    Aarav Mehta           31    aarav.mehta63@outlook.com
# 1998        1997   Ishaan Yadav           59  ishaan.yadav830@outlook.com
# 1999        1998   Aarav Sharma           77     aarav.sharma12@yahoo.com
# 2000        1999   Ishaan Joshi           77   ishaan.joshi92@outlook.com
# 2001        2000   Vivaan Singh           57    vivaan.singh214@yahoo.com
#
#      Policy_Number Policy_Type  year  Provider_Name  Coverage_Amount  \
# ...

# %% [markdown]
# ## Map()
#
# Map in pandas used to map or transform value in a single column,
#
# Map does not work on the whole data frame , it works on the only sigle columns

# %%
policy_map={
    "Basic":'B',
    "Platinum":'Plt',
    "Gold" : 'G',
    'Premium' : 'Pre'}

# %%
patient_data['policy_map']=patient_data['Policy_Type'].map(policy_map)

# %%
patient_data
# Out:
#       Patient_ID   Patient_Name  Patient_Age                        Email  \
# 0             80  Krishna Kumar           77   krishna.kumar274@yahoo.com
# 1            118      Sai Yadav           77       sai.yadav586@gmail.com
# 2             75      Sai Joshi           77     sai.joshi804@outlook.com
# 3            604   Pranav Patel           77    pranav.patel329@yahoo.com
# 4            591      Sai Reddy           77       sai.reddy717@yahoo.com
# ...          ...            ...          ...                          ...
# 1997        1996    Aarav Mehta           31    aarav.mehta63@outlook.com
# 1998        1997   Ishaan Yadav           59  ishaan.yadav830@outlook.com
# 1999        1998   Aarav Sharma           77     aarav.sharma12@yahoo.com
# 2000        1999   Ishaan Joshi           77   ishaan.joshi92@outlook.com
# 2001        2000   Vivaan Singh           57    vivaan.singh214@yahoo.com
#
#      Policy_Number Policy_Type  year  Provider_Name  Coverage_Amount  \
# ...

# %%
## columns split

patient_data[['First_name','Last_name']] = patient_data['Patient_Name'].str.split(" ",expand=True)

# %%
patient_data
# Out:
#       Patient_ID   Patient_Name  Patient_Age                        Email  \
# 0             80  Krishna Kumar           77   krishna.kumar274@yahoo.com
# 1            118      Sai Yadav           77       sai.yadav586@gmail.com
# 2             75      Sai Joshi           77     sai.joshi804@outlook.com
# 3            604   Pranav Patel           77    pranav.patel329@yahoo.com
# 4            591      Sai Reddy           77       sai.reddy717@yahoo.com
# ...          ...            ...          ...                          ...
# 1997        1996    Aarav Mehta           31    aarav.mehta63@outlook.com
# 1998        1997   Ishaan Yadav           59  ishaan.yadav830@outlook.com
# 1999        1998   Aarav Sharma           77     aarav.sharma12@yahoo.com
# 2000        1999   Ishaan Joshi           77   ishaan.joshi92@outlook.com
# 2001        2000   Vivaan Singh           57    vivaan.singh214@yahoo.com
#
#      Policy_Number Policy_Type  year  Provider_Name  Coverage_Amount  \
# ...

# %% [markdown]
# strip , lower , upper,Title

# %%
## strip is used to remove leading and trailing space from the string
patient_data['Patient_Name'].str.strip().str.lower()
# Out:
# 0       krishna kumar
# 1           sai yadav
# 2           sai joshi
# 3        pranav patel
# 4           sai reddy
#             ...
# 1997      aarav mehta
# 1998     ishaan yadav
# 1999     aarav sharma
# 2000     ishaan joshi
# 2001     vivaan singh
# Name: Patient_Name, Length: 2000, dtype: object

# %%
patient_data['Patient_Name'].str.lower()
# Out:
# 0       krishna kumar
# 1           sai yadav
# 2           sai joshi
# 3        pranav patel
# 4           sai reddy
#             ...
# 1997      aarav mehta
# 1998     ishaan yadav
# 1999     aarav sharma
# 2000     ishaan joshi
# 2001     vivaan singh
# Name: Patient_Name, Length: 2000, dtype: object

# %%
patient_data['Patient_Name'].str.upper()
# Out:
# 0       KRISHNA KUMAR
# 1           SAI YADAV
# 2           SAI JOSHI
# 3        PRANAV PATEL
# 4           SAI REDDY
#             ...
# 1997      AARAV MEHTA
# 1998     ISHAAN YADAV
# 1999     AARAV SHARMA
# 2000     ISHAAN JOSHI
# 2001     VIVAAN SINGH
# Name: Patient_Name, Length: 2000, dtype: object

# %%
patient_data['Patient_Name'].str.title()
# Out:
# 0       Krishna Kumar
# 1           Sai Yadav
# 2           Sai Joshi
# 3        Pranav Patel
# 4           Sai Reddy
#             ...
# 1997      Aarav Mehta
# 1998     Ishaan Yadav
# 1999     Aarav Sharma
# 2000     Ishaan Joshi
# 2001     Vivaan Singh
# Name: Patient_Name, Length: 2000, dtype: object

# %% [markdown]
# Group by
# Multiple columns group by
# agg function
# pivot()
# Pivot_tables

# %%
## How many member each provider has 

patient_data.groupby(['Provider_Name'])['Patient_ID'].count()
# Out:
# Provider_Name
# HDFC Ergo          378
# ICICI Lombard      400
# India Insurance    421
# Max Bupa           396
# Star Health        405
# Name: Patient_ID, dtype: int64

# %%
## how many patient has insurence more than one provider

patient_data.groupby(['Patient_Name'])['Provider_Name'].count()
# Out:
# Patient_Name
# Aarav Gupta      14
# Aarav Joshi      25
# Aarav Kumar      22
# Aarav Mehta      22
# Aarav Patel      16
#                  ..
# Vivaan Reddy     22
# Vivaan Sharma    21
# Vivaan Singh     23
# Vivaan Verma     24
# Vivaan Yadav     16
# Name: Provider_Name, Length: 100, dtype: int64

# %%
## average coverage amount by each provider

result=patient_data.groupby(['Provider_Name'])['Coverage_Amount'].mean().reset_index()

# %%
result.to_csv('result.csv',index=False)

# %%
patient_data.head()
# Out:
#    Patient_ID   Patient_Name  Patient_Age                       Email  \
# 0          80  Krishna Kumar           77  krishna.kumar274@yahoo.com
# 1         118      Sai Yadav           77      sai.yadav586@gmail.com
# 2          75      Sai Joshi           77    sai.joshi804@outlook.com
# 3         604   Pranav Patel           77   pranav.patel329@yahoo.com
# 4         591      Sai Reddy           77      sai.reddy717@yahoo.com
#
#   Policy_Number Policy_Type  year Provider_Name  Coverage_Amount  Start_Year  \
# 0     POL078226    Platinum  2025     HDFC Ergo           851420        2026
# 1     POL034543    Platinum  2025   Star Health           829205        2023
# 2     POL875971     Premium  2025   Star Health           659481        2025
# 3     POL097005     Premium  2025     HDFC Ergo           135569        2026
# 4     POL640591     Premium  2025     HDFC Ergo           954316        2026
#
#   Patient_Age_category Mask_Age_example Age_remark Email_domain  \
# ...

# %%
## how much coverage amount each provider is given in each category of age

patient_data.groupby(['Age_remark','Provider_Name'])['Coverage_Amount'].sum().reset_index()
# Out:
# C:\Users\prash\AppData\Local\Temp\ipykernel_23316\1707806099.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   patient_data.groupby(['Age_remark','Provider_Name'])['Coverage_Amount'].sum().reset_index()
#      Age_remark    Provider_Name  Coverage_Amount
# 0         Young        HDFC Ergo         40895924
# 1         Young    ICICI Lombard         31574824
# 2         Young  India Insurance         53266954
# 3         Young         Max Bupa         49059856
# 4         Young      Star Health         53443043
# 5    Middle Age        HDFC Ergo         70366073
# 6    Middle Age    ICICI Lombard         64124543
# 7    Middle Age  India Insurance         65881681
# 8    Middle Age         Max Bupa         71966464
# 9    Middle Age      Star Health         81454103
# ...

# %%
patient_data
# Out:
#       Patient_ID   Patient_Name  Patient_Age                        Email  \
# 0             80  Krishna Kumar           77   krishna.kumar274@yahoo.com
# 1            118      Sai Yadav           77       sai.yadav586@gmail.com
# 2             75      Sai Joshi           77     sai.joshi804@outlook.com
# 3            604   Pranav Patel           77    pranav.patel329@yahoo.com
# 4            591      Sai Reddy           77       sai.reddy717@yahoo.com
# ...          ...            ...          ...                          ...
# 1997        1996    Aarav Mehta           31    aarav.mehta63@outlook.com
# 1998        1997   Ishaan Yadav           59  ishaan.yadav830@outlook.com
# 1999        1998   Aarav Sharma           77     aarav.sharma12@yahoo.com
# 2000        1999   Ishaan Joshi           77   ishaan.joshi92@outlook.com
# 2001        2000   Vivaan Singh           57    vivaan.singh214@yahoo.com
#
#      Policy_Number Policy_Type  year  Provider_Name  Coverage_Amount  \
# ...

# %%
## i want to find out each provider count , name against Patient_name
pd.set_option("display.max_colwidth", None)

patient_data.groupby(['Patient_Name']).agg(
    provider_count=('Provider_Name','nunique'),
    provider_list=('Provider_Name',lambda x : list(x.unique()))
)
# Out:
#                provider_count  \
# Patient_Name
# Aarav Gupta                 5
# Aarav Joshi                 5
# Aarav Kumar                 5
# Aarav Mehta                 5
# Aarav Patel                 5
# ...                       ...
# Vivaan Reddy                4
# Vivaan Sharma               5
# Vivaan Singh                5
# Vivaan Verma                5
# Vivaan Yadav                5
#
#                                                                     provider_list
# Patient_Name
# Aarav Gupta    [ICICI Lombard, India Insurance, HDFC Ergo, Max Bupa, Star Health]
# Aarav Joshi    [ICICI Lombard, HDFC Ergo, India Insurance, Star Health, Max Bupa]
# Aarav Kumar    [Star Health, ICICI Lombard, HDFC Ergo, Max Bupa, India Insurance]
# Aarav Mehta    [Max Bupa, India Insurance, Star Health, HDFC Ergo, ICICI Lombard]
# Aarav Patel    [Max Bupa, HDFC Ergo, Star Health, ICICI Lombard, India Insurance]
# ...

# %%
## find the sum , min ,max, mean of coverage amount

patient_data['Coverage_Amount'].agg(['sum','max','min','mean'])
# Out:
# sum     1.087541e+09
# max     9.996760e+05
# min     1.008620e+05
# mean    5.437703e+05
# Name: Coverage_Amount, dtype: float64

# %%
patient_data.groupby(['Provider_Name']).agg(
    
    total_coverage=('Coverage_Amount',"sum"),
    Avg_coverage=('Coverage_Amount',"mean"),
    Max_coverage=('Coverage_Amount',"max"),
    min_coverage=('Coverage_Amount','min')
    
    
    
)
# Out:
#                  total_coverage   Avg_coverage  Max_coverage  min_coverage
# Provider_Name
# HDFC Ergo             205841974  544555.486772        997547        102853
# ICICI Lombard         207489912  518724.780000        995568        100862
# India Insurance       224222704  532595.496437        999111        103691
# Max Bupa              219013055  553063.270202        997544        103883
# Star Health           230973010  570303.728395        999676        103211

# %% [markdown]
# ## Pivot and Pivot tables
#
# Both pivot and pivot tables convert the data , reshape the data (row converts into columns)
#
# `syntax of pivot `
#
# df.pivot(index, columns , values)
#
#
# - pivot() is used to reshape data but it cannot handle duplicate values.
# - pivot_table() is more powerful because it supports aggregation functions like sum, mean, count, etc.

# %%
patient_data.pivot(columns='Provider_Name',values='Coverage_Amount')
# Out:
# Provider_Name  HDFC Ergo  ICICI Lombard  India Insurance  Max Bupa  \
# 0               851420.0            NaN              NaN       NaN
# 1                    NaN            NaN              NaN       NaN
# 2                    NaN            NaN              NaN       NaN
# 3               135569.0            NaN              NaN       NaN
# 4               954316.0            NaN              NaN       NaN
# ...                  ...            ...              ...       ...
# 1997                 NaN            NaN              NaN       NaN
# 1998                 NaN            NaN              NaN       NaN
# 1999                 NaN            NaN              NaN  644437.0
# 2000                 NaN            NaN              NaN  965221.0
# 2001                 NaN       213392.0              NaN       NaN
#
# Provider_Name  Star Health
# 0                      NaN
# 1                 829205.0
# 2                 659481.0
# 3                      NaN
# ...

# %%
## pivot_table

## Want to analyze the coverage amount by provider name and policy type

patient_data.pivot_table(index='Provider_Name',columns='Policy_Type',values='Coverage_Amount',aggfunc=['sum','mean'])
# Out:
#                       sum                                         mean  \
# Policy_Type         Basic      Gold  Platinum   Premium          Basic
# Provider_Name
# HDFC Ergo        46728285  47873876  58342716  52897097  507916.141304
# ICICI Lombard    44534618  56220861  61306940  45427493  517844.395349
# India Insurance  58156330  63626761  52910224  49529389  528693.909091
# Max Bupa         53088825  52601759  52713565  60608906  558829.736842
# Star Health      60751334  53364804  56668074  60188798  607513.340000
#
#
# Policy_Type               Gold       Platinum        Premium
# Provider_Name
# HDFC Ergo        526086.549451  571987.411765  568785.989247
# ICICI Lombard    535436.771429  542539.292035  473203.052083
# India Insurance  563068.681416  539900.244898  495293.890000
# Max Bupa         531330.898990  554879.631579  566438.373832
# Star Health      550152.618557  566680.740000  557303.685185

# %%
patient_data.pivot_table(index='Provider_Name',columns='Policy_Type',values=["Coverage_Amount","Patient_Name"],aggfunc={"Coverage_Amount":["sum","mean"],
                                                                                                             "Patient_Name":"nunique"})
# Out:
#                 Coverage_Amount                                               \
#                            mean
# Policy_Type               Basic           Gold       Platinum        Premium
# Provider_Name
# HDFC Ergo         507916.141304  526086.549451  571987.411765  568785.989247
# ICICI Lombard     517844.395349  535436.771429  542539.292035  473203.052083
# India Insurance   528693.909091  563068.681416  539900.244898  495293.890000
# Max Bupa          558829.736842  531330.898990  554879.631579  566438.373832
# Star Health       607513.340000  550152.618557  566680.740000  557303.685185
#
#                                                         Patient_Name       \
#                       sum                                    nunique
# Policy_Type         Basic      Gold  Platinum   Premium        Basic Gold
# Provider_Name
# HDFC Ergo        46728285  47873876  58342716  52897097           59   61
# ...

# %% [markdown]
# ## Stack
#
# convert the dataframe wider to longer.
#
# Stack : stacking is process of transformation of multiple columns into single columns.

# %%
stack_data=patient_data.stack()

# %%
stack_data[0:150]
# Out:
# 0  Patient_ID                               80
#    Patient_Name                  Krishna Kumar
#    Patient_Age                              77
#    Email            krishna.kumar274@yahoo.com
#    Policy_Number                     POL078226
#                                ...
# 8  Patient_Name                   Ishaan Verma
#    Patient_Age                              77
#    Email             ishaan.verma174@yahoo.com
#    Policy_Number                     POL142431
#    Policy_Type                         Premium
# Length: 150, dtype: object

# %%
stack_data.to_csv("stack.csv")

# %%
stack_data.unstack()
# Out:
#      Patient_ID   Patient_Name Patient_Age                        Email  \
# 0            80  Krishna Kumar          77   krishna.kumar274@yahoo.com
# 1           118      Sai Yadav          77       sai.yadav586@gmail.com
# 2            75      Sai Joshi          77     sai.joshi804@outlook.com
# 3           604   Pranav Patel          77    pranav.patel329@yahoo.com
# 4           591      Sai Reddy          77       sai.reddy717@yahoo.com
# ...         ...            ...         ...                          ...
# 1997       1996    Aarav Mehta          31    aarav.mehta63@outlook.com
# 1998       1997   Ishaan Yadav          59  ishaan.yadav830@outlook.com
# 1999       1998   Aarav Sharma          77     aarav.sharma12@yahoo.com
# 2000       1999   Ishaan Joshi          77   ishaan.joshi92@outlook.com
# 2001       2000   Vivaan Singh          57    vivaan.singh214@yahoo.com
#
#      Policy_Number Policy_Type  year  Provider_Name Coverage_Amount  \
# ...

# %%
df1= patient_data.set_index(['Patient_Name','Patient_Age'])

# %%
df2=df1.stack()

# %%
df2[0:20]
# Out:
# Patient_Name   Patient_Age
# Krishna Kumar  77           Patient_ID                                      80
#                             Email                   krishna.kumar274@yahoo.com
#                             Policy_Number                            POL078226
#                             Policy_Type                               Platinum
#                             year                                          2025
#                             Provider_Name                            HDFC Ergo
#                             Coverage_Amount                             851420
#                             Start_Year                                    2026
#                             Patient_Age_category                     Older Age
#                             Mask_Age_example                         Older Age
#                             Age_remark                                  Senior
# ...

# %%
df2.unstack()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[189], line 1
# ----> 1 df2.unstack()
#
# File c:\Users\prash\anaconda3\Lib\site-packages\pandas\core\series.py:4615, in Series.unstack(self, level, fill_value, sort)
#    4570 """
#    4571 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4572
#    (...)
#    4611 b    2    4
#    4612 """
#    4613 from pandas.core.reshape.reshape import unstack
# -> 4615 return unstack(self, level, fill_value, sort)
#
# File c:\Users\prash\anaconda3\Lib\site-packages\pandas\core\reshape\reshape.py:517, in unstack(obj, level, fill_value, sort)
#     515 if is_1d_only_ea_dtype(obj.dtype):
#     516     return _unstack_extension_series(obj, level, fill_value, sort=sort)
# --> 517 unstacker = _Unstacker(
#     518     obj.index, level=level, constructor=obj._constructor_expanddim, sort=sort
#     519 )
# ...

# %%
pd.set_option("display.max_rows", 200)

df2.xs("Aditya Yadav")
# Out:
# Patient_Age
# 77           Patient_ID                             705
#              Email            aditya.yadav977@gmail.com
#              Policy_Number                    POL543738
#              Policy_Type                       Platinum
#              year                                  2025
#                                         ...
# 18           Email_domain                     gmail.com
#              risk_factor                Age is below 50
#              policy_map                               G
#              First_name                          Aditya
#              Last_name                            Yadav
# Length: 336, dtype: object

# %%
patient_data[patient_data["Patient_Name"]=="Aditya Yadav"]
# Out:
#       Patient_ID  Patient_Name  Patient_Age                        Email  \
# 11           705  Aditya Yadav           77    aditya.yadav977@gmail.com
# 223          714  Aditya Yadav           77  aditya.yadav734@outlook.com
# 224          207  Aditya Yadav           77    aditya.yadav433@gmail.com
# 359          270  Aditya Yadav           57    aditya.yadav815@yahoo.com
# 412            8  Aditya Yadav           53  aditya.yadav682@outlook.com
# 507          440  Aditya Yadav           48  aditya.yadav516@outlook.com
# 520          437  Aditya Yadav           47  aditya.yadav831@outlook.com
# 630           44  Aditya Yadav           39    aditya.yadav389@yahoo.com
# 1042        1043  Aditya Yadav           49    aditya.yadav917@gmail.com
# 1051        1052  Aditya Yadav           54  aditya.yadav448@outlook.com
# 1117        1118  Aditya Yadav           77  aditya.yadav981@outlook.com
# 1137        1138  Aditya Yadav           58    aditya.yadav749@gmail.com
# ...

# %% [markdown]
# ## Cross Tab
# crosstab created frequency table between two or more columns

# %%
pd.crosstab(patient_data["Provider_Name"],patient_data['Policy_Type'])
# Out:
# Policy_Type      Basic  Gold  Platinum  Premium
# Provider_Name
# HDFC Ergo           92    91       102       93
# ICICI Lombard       86   105       113       96
# India Insurance    110   113        98      100
# Max Bupa            95    99        95      107
# Star Health        100    97       100      108

# %%
patient_data.pivot_table(index='Provider_Name',columns='Policy_Type',values='Patient_Age',aggfunc='count')
# Out:
# Policy_Type      Basic  Gold  Platinum  Premium
# Provider_Name
# HDFC Ergo           92    91       102       93
# ICICI Lombard       86   105       113       96
# India Insurance    110   113        98      100
# Max Bupa            95    99        95      107
# Star Health        100    97       100      108

# %%
pd.crosstab(patient_data['Patient_Age_category'],patient_data['Policy_Type'])
# Out:
# Policy_Type           Basic  Gold  Platinum  Premium
# Patient_Age_category
# Early Older              80    70        72       67
# Middle Age              149   170       158      166
# Older Age               175   160       171      175
# Young                    79   105       107       96

# %% [markdown]
# ## Rank
#
# The Rank method assign the rank to values in dataframe and series.
# By default rank is in ascending order

# %%
result=patient_data.groupby('Policy_Type')['Coverage_Amount'].sum().reset_index()

# %%
result['rank']=result['Coverage_Amount'].rank(ascending=False, method='dense')

# %%
result
# Out:
#   Policy_Type  Coverage_Amount  rank
# 0       Basic        263259392   4.0
# 1        Gold        273688061   2.0
# 2    Platinum        281941519   1.0
# 3     Premium        268651683   3.0

# %%
## find out top 1 policy type in each year

result=patient_data.groupby(['Start_Year','Policy_Type'])['Coverage_Amount'].sum().reset_index()

# %%
result['rank']=result.groupby('Start_Year')['Coverage_Amount'].rank(method='dense')

# %%
result[result['rank']==1.0]
# Out:
#     Start_Year Policy_Type  Coverage_Amount  rank
# 1         2023        Gold         62449381   1.0
# 7         2024     Premium         60833575   1.0
# 8         2025       Basic         67276949   1.0
# 15        2026     Premium         62277460   1.0

# %% [markdown]
# Rolling window()
# Rolling window in Pandas is used when you want to perform calculation on fixed-size moving window of rows
#
# it is used in
#
# - Time series
# - Moving Average
# - Trend Analysis
# - smoothing data
#
# rolling window apply calculation on the moving group or rows instant of the entire datasets

# %%
patient_data['Coverage_Amount'].rolling(3).mean()
# Out:
# 0                 NaN
# 1                 NaN
# 2       780035.333333
# 3       541418.333333
# 4       583122.000000
#             ...
# 1997    695307.000000
# 1998    623971.333333
# 1999    569348.000000
# 2000    729724.333333
# 2001    607683.333333
# Name: Coverage_Amount, Length: 2000, dtype: float64

# %%
patient_data['Coverage_Amount']
# Out:
# 0       851420
# 1       829205
# 2       659481
# 3       135569
# 4       954316
#          ...
# 1997    484092
# 1998    579515
# 1999    644437
# 2000    965221
# 2001    213392
# Name: Coverage_Amount, Length: 2000, dtype: int64

# %%
# Rolling Average Coverage Amount per Policy Type (over years)

patient_data.sort_values(["Policy_Type", "Start_Year"],inplace=True)

# %%
patient_data
# Out:
#       Patient_ID   Patient_Name  Patient_Age                         Email  \
# 17           340   Ishaan Kumar           77   ishaan.kumar451@outlook.com
# 30           384    Aarav Singh           77      aarav.singh557@yahoo.com
# 40           880  Reyansh Mehta           77  reyansh.mehta554@outlook.com
# 52           912      Sai Kumar           77      sai.kumar119@outlook.com
# 87           213    Arjun Reddy           77      arjun.reddy424@gmail.com
# ...          ...            ...          ...                           ...
# 1954        1953   Aditya Joshi           31   aditya.joshi357@outlook.com
# 1967        1966   Vihaan Mehta           77   vihaan.mehta781@outlook.com
# 1968        1967  Reyansh Joshi           33    reyansh.joshi279@yahoo.com
# 1982        1981      Sai Verma           77        sai.verma933@gmail.com
# 1991        1990  Krishna Yadav           49    krishna.yadav340@yahoo.com
#
# ...

# %%
patient_data['rolling_avg']=(patient_data.groupby(['Policy_Type','Start_Year'])['Coverage_Amount'].transform(lambda x : x.rolling(window=3,min_periods=1).mean())
                             
                             )

# %%
patient_data
# Out:
#       Patient_ID   Patient_Name  Patient_Age                         Email  \
# 17           340   Ishaan Kumar           77   ishaan.kumar451@outlook.com
# 30           384    Aarav Singh           77      aarav.singh557@yahoo.com
# 40           880  Reyansh Mehta           77  reyansh.mehta554@outlook.com
# 52           912      Sai Kumar           77      sai.kumar119@outlook.com
# 87           213    Arjun Reddy           77      arjun.reddy424@gmail.com
# ...          ...            ...          ...                           ...
# 1954        1953   Aditya Joshi           31   aditya.joshi357@outlook.com
# 1967        1966   Vihaan Mehta           77   vihaan.mehta781@outlook.com
# 1968        1967  Reyansh Joshi           33    reyansh.joshi279@yahoo.com
# 1982        1981      Sai Verma           77        sai.verma933@gmail.com
# 1991        1990  Krishna Yadav           49    krishna.yadav340@yahoo.com
#
# ...

# %% [markdown]
# ## Resampling in the pandas
#
# resampling mostly used with datetime data when you have data in one frequency and you want to convery that into another time frequency

# %%
import pandas as pd
import numpy as np

# create date range
dates = pd.date_range(start="2024-01-01", periods=800, freq="D")

# create dataframe
df = pd.DataFrame({
    "Date": dates,
    "Sales": np.random.randint(100,500,800)
})

df.set_index("Date", inplace=True)

# %%
df
# Out:
#             Sales
# Date
# 2024-01-01    499
# 2024-01-02    470
# 2024-01-03    462
# 2024-01-04    145
# 2024-01-05    144
# ...           ...
# 2026-03-06    487
# 2026-03-07    445
# 2026-03-08    229
# 2026-03-09    444
# 2026-03-10    229
#
# [800 rows x 1 columns]

# %%
## week wise sales
df.resample("W").sum()
# Out:
#             Sales
# Date
# 2024-01-07   2450
# 2024-01-14   1953
# 2024-01-21   2402
# 2024-01-28   2267
# 2024-02-04   1810
# 2024-02-11   2173
# 2024-02-18   2623
# 2024-02-25   2493
# 2024-03-03   1116
# 2024-03-10   2330
# 2024-03-17   1796
# 2024-03-24   1240
# 2024-03-31   2381
# 2024-04-07   1929
# 2024-04-14   2610
# 2024-04-21   1859
# 2024-04-28   2182
# 2024-05-05   2560
# 2024-05-12   2061
# 2024-05-19   2209
# 2024-05-26   2036
# 2024-06-02   1941
# 2024-06-09   2715
# 2024-06-16   1606
# 2024-06-23   2158
# 2024-06-30   1984
# 2024-07-07   2274
# 2024-07-14   1737
# 2024-07-21   1919
# 2024-07-28   2241
# 2024-08-04   2062
# 2024-08-11   1942
# 2024-08-18   2051
# 2024-08-25   2270
# 2024-09-01   2165
# 2024-09-08   1737
# 2024-09-15   2613
# 2024-09-22   2012
# 2024-09-29   1897
# 2024-10-06   2418
# 2024-10-13   1567
# 2024-10-20   2465
# 2024-10-27   2135
# 2024-11-03   2415
# 2024-11-10   2119
# 2024-11-17   2031
# 2024-11-24   2257
# 2024-12-01   2432
# ...

# %%
df.resample("W").agg(["sum","mean","max"])
# Out:
#            Sales
#              sum        mean  max
# Date
# 2024-01-07  2450  350.000000  499
# 2024-01-14  1953  279.000000  490
# 2024-01-21  2402  343.142857  496
# 2024-01-28  2267  323.857143  473
# 2024-02-04  1810  258.571429  447
# 2024-02-11  2173  310.428571  465
# 2024-02-18  2623  374.714286  480
# 2024-02-25  2493  356.142857  491
# 2024-03-03  1116  159.428571  267
# 2024-03-10  2330  332.857143  397
# 2024-03-17  1796  256.571429  495
# 2024-03-24  1240  177.142857  271
# 2024-03-31  2381  340.142857  471
# 2024-04-07  1929  275.571429  456
# 2024-04-14  2610  372.857143  484
# 2024-04-21  1859  265.571429  451
# 2024-04-28  2182  311.714286  464
# 2024-05-05  2560  365.714286  488
# 2024-05-12  2061  294.428571  462
# 2024-05-19  2209  315.571429  494
# 2024-05-26  2036  290.857143  495
# 2024-06-02  1941  277.285714  444
# 2024-06-09  2715  387.857143  480
# 2024-06-16  1606  229.428571  424
# 2024-06-23  2158  308.285714  493
# 2024-06-30  1984  283.428571  450
# ...

# %%
## monthly sales
df.resample("M").sum()
# Out:
# C:\Users\prash\AppData\Local\Temp\ipykernel_23316\963759446.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.resample("M").sum()
#             Sales
# Date
# 2024-01-31   9765
# 2024-02-29   9019
# 2024-03-31   8250
# 2024-04-30   9165
# 2024-05-31   9646
# 2024-06-30   9039
# 2024-07-31   8964
# 2024-08-31   9463
# 2024-09-30   8984
# 2024-10-31   9495
# 2024-11-30   9400
# 2024-12-31   9320
# 2025-01-31  10418
# 2025-02-28  10021
# 2025-03-31   9019
# 2025-04-30   8806
# 2025-05-31  10157
# 2025-06-30   9336
# 2025-07-31   9785
# 2025-08-31   9953
# 2025-09-30   9106
# 2025-10-31   8497
# 2025-11-30   9203
# 2025-12-31   9348
# 2026-01-31   9392
# 2026-02-28   8503
# 2026-03-31   3090

# %%
df.resample("Y").sum()
# Out:
# C:\Users\prash\AppData\Local\Temp\ipykernel_23316\3008989606.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df.resample("Y").sum()
#              Sales
# Date
# 2024-12-31  110510
# 2025-12-31  113649
# 2026-12-31   20985

# %%
patient_data
# Out:
#       Patient_ID   Patient_Name  Patient_Age                         Email  \
# 17           340   Ishaan Kumar           77   ishaan.kumar451@outlook.com
# 30           384    Aarav Singh           77      aarav.singh557@yahoo.com
# 40           880  Reyansh Mehta           77  reyansh.mehta554@outlook.com
# 52           912      Sai Kumar           77      sai.kumar119@outlook.com
# 87           213    Arjun Reddy           77      arjun.reddy424@gmail.com
# ...          ...            ...          ...                           ...
# 1954        1953   Aditya Joshi           31   aditya.joshi357@outlook.com
# 1967        1966   Vihaan Mehta           77   vihaan.mehta781@outlook.com
# 1968        1967  Reyansh Joshi           33    reyansh.joshi279@yahoo.com
# 1982        1981      Sai Verma           77        sai.verma933@gmail.com
# 1991        1990  Krishna Yadav           49    krishna.yadav340@yahoo.com
#
# ...

# %%
data = {
    "timestamp":[
        "2025-01-01T10:30:45",
        "2025-02-23T10:30:45",
        "2025-03-31T09:20:10",
        "2025-06-30T12:45:30",
        "2025-12-31T23:10:05"
    ]
}

# %%
data
# Out:
# {'timestamp': ['2025-01-01T10:30:45',
#   '2025-02-23T10:30:45',
#   '2025-03-31T09:20:10',
#   '2025-06-30T12:45:30',
#   '2025-12-31T23:10:05']}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#              timestamp
# 0  2025-01-01T10:30:45
# 1  2025-02-23T10:30:45
# 2  2025-03-31T09:20:10
# 3  2025-06-30T12:45:30
# 4  2025-12-31T23:10:05

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  5 non-null      object
# dtypes: object(1)
# memory usage: 172.0+ bytes

# %%
df["datetime"]=pd.to_datetime(df["timestamp"])

# %%
df
# Out:
#              timestamp            datetime
# 0  2025-01-01T10:30:45 2025-01-01 10:30:45
# 1  2025-02-23T10:30:45 2025-02-23 10:30:45
# 2  2025-03-31T09:20:10 2025-03-31 09:20:10
# 3  2025-06-30T12:45:30 2025-06-30 12:45:30
# 4  2025-12-31T23:10:05 2025-12-31 23:10:05

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  5 non-null      object
#  1   datetime   5 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 212.0+ bytes

# %%
## year from the datetime

df['year']=df['datetime'].dt.year

# %%
df
# Out:
#              timestamp            datetime  year
# 0  2025-01-01T10:30:45 2025-01-01 10:30:45  2025
# 1  2025-02-23T10:30:45 2025-02-23 10:30:45  2025
# 2  2025-03-31T09:20:10 2025-03-31 09:20:10  2025
# 3  2025-06-30T12:45:30 2025-06-30 12:45:30  2025
# 4  2025-12-31T23:10:05 2025-12-31 23:10:05  2025

# %%
## month from date time

df['Month']= df['datetime'].dt.month

# %%
df
# Out:
#              timestamp            datetime  year  Month
# 0  2025-01-01T10:30:45 2025-01-01 10:30:45  2025      1
# 1  2025-02-23T10:30:45 2025-02-23 10:30:45  2025      2
# 2  2025-03-31T09:20:10 2025-03-31 09:20:10  2025      3
# 3  2025-06-30T12:45:30 2025-06-30 12:45:30  2025      6
# 4  2025-12-31T23:10:05 2025-12-31 23:10:05  2025     12

# %%
## extract month name from the date time columns

df["Month_Name"]=df['datetime'].dt.month_name()

# %%
df
# Out:
#              timestamp            datetime  year  Month Month_Name
# 0  2025-01-01T10:30:45 2025-01-01 10:30:45  2025      1    January
# 1  2025-02-23T10:30:45 2025-02-23 10:30:45  2025      2   February
# 2  2025-03-31T09:20:10 2025-03-31 09:20:10  2025      3      March
# 3  2025-06-30T12:45:30 2025-06-30 12:45:30  2025      6       June
# 4  2025-12-31T23:10:05 2025-12-31 23:10:05  2025     12   December

# %%
## extract day_name from the datetime

df['Day_Name']=df['datetime'].dt.day_name()

# %%
df
# Out:
#              timestamp            datetime  year  Month Month_Name   Day_Name
# 0  2025-01-01T10:30:45 2025-01-01 10:30:45  2025      1    January  Wednesday
# 1  2025-02-23T10:30:45 2025-02-23 10:30:45  2025      2   February     Sunday
# 2  2025-03-31T09:20:10 2025-03-31 09:20:10  2025      3      March     Monday
# 3  2025-06-30T12:45:30 2025-06-30 12:45:30  2025      6       June     Monday
# 4  2025-12-31T23:10:05 2025-12-31 23:10:05  2025     12   December  Wednesday

# %%
##check day is weekday or weekend

df['is_Weekend']=df['datetime'].dt.dayofweek>4

# %%
df
# Out:
#              timestamp            datetime  year  Month Month_Name   Day_Name  \
# 0  2025-01-01T10:30:45 2025-01-01 10:30:45  2025      1    January  Wednesday
# 1  2025-02-23T10:30:45 2025-02-23 10:30:45  2025      2   February     Sunday
# 2  2025-03-31T09:20:10 2025-03-31 09:20:10  2025      3      March     Monday
# 3  2025-06-30T12:45:30 2025-06-30 12:45:30  2025      6       June     Monday
# 4  2025-12-31T23:10:05 2025-12-31 23:10:05  2025     12   December  Wednesday
#
#    is_Weekend
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False

# %%
def is_weekend(df):
    if df['Day_Name']=='Sunday' or df['Day_Name']== 'Saturday':
        return "Weekend"
    else:
        return 'Weekday'

# %%
df.columns
# Out:
# Index(['timestamp', 'datetime', 'year', 'Month', 'Month_Name', 'Day_Name',
#        'is_Weekend'],
#       dtype='object')

# %%
df['is_Weekend_2']=df.apply(is_weekend,axis=1)

# %%
df
# Out:
#              timestamp            datetime  year  Month Month_Name   Day_Name  \
# 0  2025-01-01T10:30:45 2025-01-01 10:30:45  2025      1    January  Wednesday
# 1  2025-02-23T10:30:45 2025-02-23 10:30:45  2025      2   February     Sunday
# 2  2025-03-31T09:20:10 2025-03-31 09:20:10  2025      3      March     Monday
# 3  2025-06-30T12:45:30 2025-06-30 12:45:30  2025      6       June     Monday
# 4  2025-12-31T23:10:05 2025-12-31 23:10:05  2025     12   December  Wednesday
#
#    is_Weekend is_Weekend_2
# 0       False      Weekday
# 1        True      Weekend
# 2       False      Weekday
# 3       False      Weekday
# 4       False      Weekday

# %%
df['quarter']=df['datetime'].dt.quarter

# %%
df
# Out:
#              timestamp            datetime  year  Month Month_Name   Day_Name  \
# 0  2025-01-01T10:30:45 2025-01-01 10:30:45  2025      1    January  Wednesday
# 1  2025-02-23T10:30:45 2025-02-23 10:30:45  2025      2   February     Sunday
# 2  2025-03-31T09:20:10 2025-03-31 09:20:10  2025      3      March     Monday
# 3  2025-06-30T12:45:30 2025-06-30 12:45:30  2025      6       June     Monday
# 4  2025-12-31T23:10:05 2025-12-31 23:10:05  2025     12   December  Wednesday
#
#    is_Weekend is_Weekend_2  quarter
# 0       False      Weekday        1
# 1        True      Weekend        1
# 2       False      Weekday        1
# 3       False      Weekday        2
# 4       False      Weekday        4

# %%
df['is_leap_year'] = df['datetime'].dt.is_leap_year

# %%
df
# Out:
#              timestamp            datetime  year  Month Month_Name   Day_Name  \
# 0  2025-01-01T10:30:45 2025-01-01 10:30:45  2025      1    January  Wednesday
# 1  2025-02-23T10:30:45 2025-02-23 10:30:45  2025      2   February     Sunday
# 2  2025-03-31T09:20:10 2025-03-31 09:20:10  2025      3      March     Monday
# 3  2025-06-30T12:45:30 2025-06-30 12:45:30  2025      6       June     Monday
# 4  2025-12-31T23:10:05 2025-12-31 23:10:05  2025     12   December  Wednesday
#
#    is_Weekend is_Weekend_2  quarter  is_leap_year
# 0       False      Weekday        1         False
# 1        True      Weekend        1         False
# 2       False      Weekday        1         False
# 3       False      Weekday        2         False
# 4       False      Weekday        4         False

# %%
## weeknumber of the year

df['week_number']=df['datetime'].dt.isocalendar().week

# %%
df
# Out:
#              timestamp            datetime  year  Month Month_Name   Day_Name  \
# 0  2025-01-01T10:30:45 2025-01-01 10:30:45  2025      1    January  Wednesday
# 1  2025-02-23T10:30:45 2025-02-23 10:30:45  2025      2   February     Sunday
# 2  2025-03-31T09:20:10 2025-03-31 09:20:10  2025      3      March     Monday
# 3  2025-06-30T12:45:30 2025-06-30 12:45:30  2025      6       June     Monday
# 4  2025-12-31T23:10:05 2025-12-31 23:10:05  2025     12   December  Wednesday
#
#    is_Weekend is_Weekend_2  quarter  is_leap_year  week_number
# 0       False      Weekday        1         False            1
# 1        True      Weekend        1         False            8
# 2       False      Weekday        1         False           14
# 3       False      Weekday        2         False           27
# 4       False      Weekday        4         False            1

# %%
## day of the year

df['day_of_year']= df['datetime'].dt.dayofyear

# %%
df
# Out:
#              timestamp            datetime  year  Month Month_Name   Day_Name  \
# 0  2025-01-01T10:30:45 2025-01-01 10:30:45  2025      1    January  Wednesday
# 1  2025-02-23T10:30:45 2025-02-23 10:30:45  2025      2   February     Sunday
# 2  2025-03-31T09:20:10 2025-03-31 09:20:10  2025      3      March     Monday
# 3  2025-06-30T12:45:30 2025-06-30 12:45:30  2025      6       June     Monday
# 4  2025-12-31T23:10:05 2025-12-31 23:10:05  2025     12   December  Wednesday
#
#    is_Weekend is_Weekend_2  quarter  is_leap_year  week_number  day_of_year
# 0       False      Weekday        1         False            1            1
# 1        True      Weekend        1         False            8           54
# 2       False      Weekday        1         False           14           90
# 3       False      Weekday        2         False           27          181
# 4       False      Weekday        4         False            1          365

# %%
## how to extract hours , minutes and second
df['hours']=df['datetime'].dt.hour

# %%
df['minutes']=df['datetime'].dt.minute

# %%
df['second']=df['datetime'].dt.second

# %%
df
# Out:
#              timestamp            datetime  year  Month Month_Name   Day_Name  \
# 0  2025-01-01T10:30:45 2025-01-01 10:30:45  2025      1    January  Wednesday
# 1  2025-02-23T10:30:45 2025-02-23 10:30:45  2025      2   February     Sunday
# 2  2025-03-31T09:20:10 2025-03-31 09:20:10  2025      3      March     Monday
# 3  2025-06-30T12:45:30 2025-06-30 12:45:30  2025      6       June     Monday
# 4  2025-12-31T23:10:05 2025-12-31 23:10:05  2025     12   December  Wednesday
#
#    is_Weekend is_Weekend_2  quarter  is_leap_year  week_number  day_of_year  \
# 0       False      Weekday        1         False            1            1
# 1        True      Weekend        1         False            8           54
# 2       False      Weekday        1         False           14           90
# 3       False      Weekday        2         False           27          181
# 4       False      Weekday        4         False            1          365
#
#    hours  minutes  second
# ...

# %%
## how to save the data into csv and excel 

file_name='date.csv'


df.to_csv(file_name,index=False)

# %%
import os 

dir_path = os.path.expanduser('~\downloads')

print(dir_path)

folder_name= 'datayt_check_list_import'

folder_path = os.path.join(dir_path,folder_name)

print(folder_path)

os.makedirs(folder_path,exist_ok=True)

file_name= 'data.csv'

file_path = os.path.join(folder_path,file_name)

print(file_path)

df.to_csv(file_path,index=False)
# Out:
# C:\Users\prash\downloads
# C:\Users\prash\downloads\datayt_check_list_import
# C:\Users\prash\downloads\datayt_check_list_import\data.csv
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\prash\AppData\Local\Temp\ipykernel_23316\410969058.py:3: SyntaxWarning: invalid escape sequence '\d'
#   dir_path = os.path.expanduser('~\downloads')

# %%
df1 = pd.DataFrame({
    "Name": ["Amit", "Ravi", "Priya"],
    "Age": [25, 30, 28]
})

df2 = pd.DataFrame({
    "Product": ["Laptop", "Phone", "Tablet"],
    "Price": [80000, 30000, 25000]
})

# %%
df1
# Out:
#     Name  Age
# 0   Amit   25
# 1   Ravi   30
# 2  Priya   28

# %%
df2
# Out:
#   Product  Price
# 0  Laptop  80000
# 1   Phone  30000
# 2  Tablet  25000

# %%
dir_path = os.path.expanduser('~\downloads')

print(dir_path)

folder_name= 'excel_data_from_pandas'

folder_path = os.path.join(dir_path,folder_name)

print(folder_path)

os.makedirs(folder_path,exist_ok=True)

excel_path='product.xlsx'

file_path = os.path.join(folder_path,excel_path)

print(file_path)
# Out:
# C:\Users\prash\downloads
# C:\Users\prash\downloads\excel_data_from_pandas
# C:\Users\prash\downloads\excel_data_from_pandas\product.xlsx
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\prash\AppData\Local\Temp\ipykernel_23316\2166179243.py:1: SyntaxWarning: invalid escape sequence '\d'
#   dir_path = os.path.expanduser('~\downloads')

# %%
writer = pd.ExcelWriter(file_path)

df1.to_excel(writer,sheet_name='person.destails',index=False)
df2.to_excel(writer,sheet_name='product_details',index=False)

writer.close()
