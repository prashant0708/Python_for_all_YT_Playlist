# %%
import pandas as pd

# %% [markdown]
# ## What is Pandas
#
# Pandas is open-source library that is used for data manupulation and data analysis.
#
# It provide fast, flexiable and expressive data stracture.
#
# It return the data in series or dataframe that is similar to lables , relation , and tabuler data.

# %%
## create dataframe from the given dictionary

data = {
    "Name":["Amit","Rahul","Jay","Salman","Katrina","Virat"],
    "Salary":[23000, 56000, 34000,57000,56000,66000],
    "Age":[34,56,45,33,23,32]}

# %%
data
# Out:
# {'Name': ['Amit', 'Rahul', 'Jay', 'Salman', 'Katrina', 'Virat'],
#  'Salary': [23000, 56000, 34000, 57000, 56000, 66000],
#  'Age': [34, 56, 45, 33, 23, 32]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Salary  Age
# 0     Amit   23000   34
# 1    Rahul   56000   56
# 2      Jay   34000   45
# 3   Salman   57000   33
# 4  Katrina   56000   23
# 5    Virat   66000   32

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
## list to dataframe
Fruits = ["Apple","Gauva","Plam","Pomigranad","Blackberry"]
Price=[500,600,400,130,120]

# %%
fruits_data = list(zip(Fruits,Price))

# %%
fruits_data
# Out:
# [('Apple', 500),
#  ('Gauva', 600),
#  ('Plam', 400),
#  ('Pomigranad', 130),
#  ('Blackberry', 120)]

# %%
df1= pd.DataFrame(fruits_data, columns= ['Fruits','Price'])

# %%
df1
# Out:
#        Fruits  Price
# 0       Apple    500
# 1       Gauva    600
# 2        Plam    400
# 3  Pomigranad    130
# 4  Blackberry    120

# %%
## empty dataframe
df3 = pd.DataFrame()

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
df3
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df3['Fruits'] = Fruits
df3['Price']=Price

# %%
df3
# Out:
#        Fruits  Price
# 0       Apple    500
# 1       Gauva    600
# 2        Plam    400
# 3  Pomigranad    130
# 4  Blackberry    120

# %%
## function that will take n number of list to create dataframe out of that
import logging

logging.basicConfig(level=logging.INFO)

def list_to_dataframe(*lists): ## 3 list of 5 length  ### case 2 --> 3 list 5,4,5
    try:
        length_iterator = list(map(lambda x : len(x),lists)) # [5,5,5] , ##[5,4,5] -->[5,4]
        
        logging.info(f"length of each list  is length_iterator = {length_iterator}")
        
        x = set(length_iterator) # [4,4,4] --> {4}
        logging.info(f"length of x after removing the duplicate x= {x}")
        
        if len(x)!=1:
            raise ValueError("length of the given list is not same")
        else:
            data=list(zip(*lists))
            logging.info(f"here is your data after zipping{data}")
            result = pd.DataFrame(data)
        return result
    except Exception as e:
        logging.error({"type":"error", "info":str(e)})

# %%
## pass three list parameter and convert that into data frame

name= ["Rahul","Sanjeev","Sharma","Avinav"]
age = [20,24,56,45]
salary = [56000, 45000, 340000, 67000]

df4=list_to_dataframe(name,age,salary)
# Out:
# INFO:root:length of each list  is length_iterator = [4, 4, 4]
# INFO:root:length of x after removing the duplicate x= {4}
# INFO:root:here is your data after zipping[('Rahul', 20, 56000), ('Sanjeev', 24, 45000), ('Sharma', 56, 340000), ('Avinav', 45, 67000)]

# %%
df4.columns= ['name','age','Salary']

# %%
df4
# Out:
#       name  age  Salary
# 0    Rahul   20   56000
# 1  Sanjeev   24   45000
# 2   Sharma   56  340000
# 3   Avinav   45   67000

# %%
## read the data from excel

patient_file_path= r"C:\Users\prash\Desktop\Python_for_all_YT_Playlist\data\patients_data.xlsx"

patient_data = pd.read_excel(patient_file_path)

# %%
patient_data
# Out:
#      Patient_ID   Patient_Name  Age                         Email  \
# 0             1  Krishna Reddy   22  krishna.reddy835@outlook.com
# 1             2    Arjun Gupta   40    arjun.gupta570@outlook.com
# 2             3   Vivaan Singh   51      vivaan.singh72@yahoo.com
# 3             4    Arjun Kumar   36    arjun.kumar883@outlook.com
# 4             5  Krishna Verma   23    krishna.verma273@yahoo.com
# ..          ...            ...  ...                           ...
# 995         996   Vivaan Verma   32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta   67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta   27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma   49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel   72    reyansh.patel612@yahoo.com
#
#     Policy_Number Policy_Type  year
# 0       POL602544    Platinum  2025
# 1       POL856642        Gold  2025
# 2       POL512045    Platinum  2025
# ...

# %%
excel_file= pd.ExcelFile(patient_file_path)

# %%
excel_file.sheet_names
# Out:
# ['Patients_2025', 'Patients_2026']

# %%
Patients_2025_date = pd.read_excel(excel_file,sheet_name= 'Patients_2025')

# %%
Patients_2026_date = pd.read_excel(excel_file,sheet_name= 'Patients_2026')

# %%
Patients_2025_date
# Out:
#      Patient_ID   Patient_Name  Age                         Email  \
# 0             1  Krishna Reddy   22  krishna.reddy835@outlook.com
# 1             2    Arjun Gupta   40    arjun.gupta570@outlook.com
# 2             3   Vivaan Singh   51      vivaan.singh72@yahoo.com
# 3             4    Arjun Kumar   36    arjun.kumar883@outlook.com
# 4             5  Krishna Verma   23    krishna.verma273@yahoo.com
# ..          ...            ...  ...                           ...
# 995         996   Vivaan Verma   32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta   67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta   27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma   49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel   72    reyansh.patel612@yahoo.com
#
#     Policy_Number Policy_Type  year
# 0       POL602544    Platinum  2025
# 1       POL856642        Gold  2025
# 2       POL512045    Platinum  2025
# ...

# %%
Patients_2026_date
# Out:
#      Patient_ID  Patient_Name  Age                        Email Policy_Number  \
# 0          1001   Aarav Mehta   78     aarav.mehta384@yahoo.com     POL625423
# 1          1002   Aarav Verma   32     aarav.verma271@yahoo.com     POL930599
# 2          1003  Vihaan Verma   40  vihaan.verma345@outlook.com     POL456865
# 3          1004  Aditya Mehta   18  aditya.mehta579@outlook.com     POL982259
# 4          1005   Aarav Singh   39   aarav.singh126@outlook.com     POL742545
# ..          ...           ...  ...                          ...           ...
# 995        1996   Aarav Mehta   31    aarav.mehta63@outlook.com     POL748260
# 996        1997  Ishaan Yadav   59  ishaan.yadav830@outlook.com     POL725846
# 997        1998  Aarav Sharma   72     aarav.sharma12@yahoo.com     POL362369
# 998        1999  Ishaan Joshi   65   ishaan.joshi92@outlook.com     POL921223
# 999        2000  Vivaan Singh   57    vivaan.singh214@yahoo.com     POL309917
#
#     Policy_Type  Year
# ...

# %%
## read the data from the csv 

csv_file_path = r"C:\Users\prash\Desktop\Python_for_all_YT_Playlist\data\patients_data.csv"

csv_data = pd.read_csv(csv_file_path)

# %%
csv_data
# Out:
#      Patient_ID  Patient_Name  Age                        Email Policy_Number  \
# 0             1  Aditya Reddy   60  aditya.reddy437@outlook.com     POL701385
# 1             2  Aditya Verma   69  aditya.verma669@outlook.com     POL908515
# 2             3  Vivaan Reddy   58    vivaan.reddy696@yahoo.com     POL098395
# 3             4     Sai Gupta   76       sai.gupta699@gmail.com     POL802266
# 4             5  Ishaan Mehta   77  ishaan.mehta156@outlook.com     POL423233
# ..          ...           ...  ...                          ...           ...
# 995         996  Aditya Verma   41    aditya.verma839@yahoo.com     POL265181
# 996         997   Aarav Gupta   63     aarav.gupta900@gmail.com     POL797105
# 997         998  Vivaan Gupta   40    vivaan.gupta159@gmail.com     POL713191
# 998         999  Ishaan Verma   45    ishaan.verma817@gmail.com     POL146295
# 999        1000  Vihaan Patel   35    vihaan.patel222@yahoo.com     POL144496
#
#     Policy_Type
# ...

# %%
## read the data from json

json_file_path=r"C:\Users\prash\Desktop\Python_for_all_YT_Playlist\data\patients_data.json"

pd.read_json(json_file_path)
# Out:
#      Patient_ID  Patient_Name  Age                        Email Policy_Number  \
# 0             1  Aditya Reddy   60  aditya.reddy437@outlook.com     POL701385
# 1             2  Aditya Verma   69  aditya.verma669@outlook.com     POL908515
# 2             3  Vivaan Reddy   58    vivaan.reddy696@yahoo.com     POL098395
# 3             4     Sai Gupta   76       sai.gupta699@gmail.com     POL802266
# 4             5  Ishaan Mehta   77  ishaan.mehta156@outlook.com     POL423233
# ..          ...           ...  ...                          ...           ...
# 995         996  Aditya Verma   41    aditya.verma839@yahoo.com     POL265181
# 996         997   Aarav Gupta   63     aarav.gupta900@gmail.com     POL797105
# 997         998  Vivaan Gupta   40    vivaan.gupta159@gmail.com     POL713191
# 998         999  Ishaan Verma   45    ishaan.verma817@gmail.com     POL146295
# 999        1000  Vihaan Patel   35    vihaan.patel222@yahoo.com     POL144496
#
#     Policy_Type
# ...

# %%
1. dict
2. list
3. Custom function to read data from n list
4. Excel file , sheet specific
5. CSV
6. Json
# Out:
#   Cell In[42], line 1
#     1. dict
#        ^
# SyntaxError: invalid syntax

# %%
df =Patients_2025_date

# %%
df
# Out:
#      Patient_ID   Patient_Name  Age                         Email  \
# 0             1  Krishna Reddy   22  krishna.reddy835@outlook.com
# 1             2    Arjun Gupta   40    arjun.gupta570@outlook.com
# 2             3   Vivaan Singh   51      vivaan.singh72@yahoo.com
# 3             4    Arjun Kumar   36    arjun.kumar883@outlook.com
# 4             5  Krishna Verma   23    krishna.verma273@yahoo.com
# ..          ...            ...  ...                           ...
# 995         996   Vivaan Verma   32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta   67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta   27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma   49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel   72    reyansh.patel612@yahoo.com
#
#     Policy_Number Policy_Type  year
# 0       POL602544    Platinum  2025
# 1       POL856642        Gold  2025
# 2       POL512045    Platinum  2025
# ...

# %%
## how mnay rows and columns do we have

df.shape
# Out:
# (1000, 7)

# %%
df.size
# Out:
# 7000

# %%
## data types and over all view of the data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Patient_ID     1000 non-null   int64
#  1   Patient_Name   1000 non-null   object
#  2   Age            1000 non-null   int64
#  3   Email          1000 non-null   object
#  4   Policy_Number  1000 non-null   object
#  5   Policy_Type    1000 non-null   object
#  6   year           1000 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 54.8+ KB

# %%
## i want to see top 5 records
df.head()
# Out:
#    Patient_ID   Patient_Name  Age                         Email Policy_Number  \
# 0           1  Krishna Reddy   22  krishna.reddy835@outlook.com     POL602544
# 1           2    Arjun Gupta   40    arjun.gupta570@outlook.com     POL856642
# 2           3   Vivaan Singh   51      vivaan.singh72@yahoo.com     POL512045
# 3           4    Arjun Kumar   36    arjun.kumar883@outlook.com     POL132724
# 4           5  Krishna Verma   23    krishna.verma273@yahoo.com     POL060110
#
#   Policy_Type  year
# 0    Platinum  2025
# 1        Gold  2025
# 2    Platinum  2025
# 3        Gold  2025
# 4        Gold  2025

# %%
## only bottom 5 records

df.tail()
# Out:
#      Patient_ID   Patient_Name  Age                         Email  \
# 995         996   Vivaan Verma   32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta   67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta   27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma   49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel   72    reyansh.patel612@yahoo.com
#
#     Policy_Number Policy_Type  year
# 995     POL973107       Basic  2025
# 996     POL755200    Platinum  2025
# 997     POL970351     Premium  2025
# 998     POL343885     Premium  2025
# 999     POL418617     Premium  2025

# %%
## I want to see 20 records from the top

df.head(20)
# Out:
#     Patient_ID   Patient_Name  Age                         Email  \
# 0            1  Krishna Reddy   22  krishna.reddy835@outlook.com
# 1            2    Arjun Gupta   40    arjun.gupta570@outlook.com
# 2            3   Vivaan Singh   51      vivaan.singh72@yahoo.com
# 3            4    Arjun Kumar   36    arjun.kumar883@outlook.com
# 4            5  Krishna Verma   23    krishna.verma273@yahoo.com
# 5            6   Aditya Gupta   33     aditya.gupta574@yahoo.com
# 6            7   Vihaan Patel   56   vihaan.patel300@outlook.com
# 7            8   Aditya Yadav   53   aditya.yadav682@outlook.com
# 8            9      Sai Yadav   45        sai.yadav975@gmail.com
# 9           10  Aditya Sharma   23    aditya.sharma396@gmail.com
# 10          11  Reyansh Yadav   69    reyansh.yadav432@gmail.com
# 11          12   Pranav Singh   30      pranav.singh95@yahoo.com
# 12          13   Ishaan Singh   23     ishaan.singh184@gmail.com
# ...

# %%
df.tail(25)
# Out:
#      Patient_ID    Patient_Name  Age                         Email  \
# 975         976   Reyansh Patel   28   reyansh.patel62@outlook.com
# 976         977  Krishna Sharma   36   krishna.sharma255@gmail.com
# 977         978    Vivaan Yadav   44     vivaan.yadav183@gmail.com
# 978         979   Reyansh Yadav   48    reyansh.yadav654@gmail.com
# 979         980    Vihaan Gupta   29   vihaan.gupta880@outlook.com
# 980         981     Aarav Reddy   39      aarav.reddy441@gmail.com
# 981         982    Vivaan Reddy   18     vivaan.reddy710@yahoo.com
# 982         983   Reyansh Patel   20    reyansh.patel789@gmail.com
# 983         984    Aditya Reddy   56     aditya.reddy409@gmail.com
# 984         985       Sai Mehta   74       sai.mehta51@outlook.com
# 985         986    Vivaan Reddy   35   vivaan.reddy717@outlook.com
# 986         987   Krishna Singh   42   krishna.singh24@outlook.com
# 987         988   Reyansh Verma   30  reyansh.verma743@outlook.com
# ...

# %%
## I want only columns name

df.columns
# Out:
# Index(['Patient_ID', 'Patient_Name', 'Age', 'Email', 'Policy_Number',
#        'Policy_Type', 'year'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Patient_ID          Age    year
# count  1000.000000  1000.000000  1000.0
# mean    500.500000    48.075000  2025.0
# std     288.819436    18.360296     0.0
# min       1.000000    18.000000  2025.0
# 25%     250.750000    32.000000  2025.0
# 50%     500.500000    48.000000  2025.0
# 75%     750.250000    63.000000  2025.0
# max    1000.000000    80.000000  2025.0

# %%
type(df.Age)
# Out:
# pandas.core.series.Series

# %%
## Series: 


We have discussed about the dataframe but we have not discussed about the series

### What is series

Aseries in pandas is one dimensional labeled array.

It has two main part value and index(lables)

# %%
Fruits
# Out:
# ['Apple', 'Gauva', 'Plam', 'Pomigranad', 'Blackberry']

# %%
Price.append(30)

# %%
Price
# Out:
# [500, 600, 400, 130, 120, 30]

# %%
age.append(20)

# %%
age
# Out:
# [20, 24, 56, 45, 20]

# %%
name
# Out:
# ['Rahul', 'Sanjeev', 'Sharma', 'Avinav']

# %%
salary
# Out:
# [56000, 45000, 340000, 67000]

# %%
age=age[0:4]

# %%
age
# Out:
# [20, 24, 56, 45]

# %%
df
# Out:
#      Patient_ID   Patient_Name  Age                         Email  \
# 0             1  Krishna Reddy   22  krishna.reddy835@outlook.com
# 1             2    Arjun Gupta   40    arjun.gupta570@outlook.com
# 2             3   Vivaan Singh   51      vivaan.singh72@yahoo.com
# 3             4    Arjun Kumar   36    arjun.kumar883@outlook.com
# 4             5  Krishna Verma   23    krishna.verma273@yahoo.com
# ..          ...            ...  ...                           ...
# 995         996   Vivaan Verma   32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta   67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta   27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma   49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel   72    reyansh.patel612@yahoo.com
#
#     Policy_Number Policy_Type  year
# 0       POL602544    Platinum  2025
# 1       POL856642        Gold  2025
# 2       POL512045    Platinum  2025
# ...

# %%
s
# Out:
# Apple         500
# Gauva         600
# Plam          400
# Pomigranad    130
# Blackberry     30
# dtype: int64

# %%
## i want to get only one column

df.Age
# Out:
# 0      22
# 1      40
# 2      51
# 3      36
# 4      23
#        ..
# 995    32
# 996    67
# 997    27
# 998    49
# 999    72
# Name: Age, Length: 1000, dtype: int64

# %%
type(df[['Age']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['Age']
# Out:
# 0      22
# 1      40
# 2      51
# 3      36
# 4      23
#        ..
# 995    32
# 996    67
# 997    27
# 998    49
# 999    72
# Name: Age, Length: 1000, dtype: int64

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Patient_Name', 'Age', 'Email', 'Policy_Number',
#        'Policy_Type', 'year'],
#       dtype='object')

# %%
df[['Patient_Name','Age','Policy_Number']]
# Out:
#       Patient_Name  Age Policy_Number
# 0    Krishna Reddy   22     POL602544
# 1      Arjun Gupta   40     POL856642
# 2     Vivaan Singh   51     POL512045
# 3      Arjun Kumar   36     POL132724
# 4    Krishna Verma   23     POL060110
# ..             ...  ...           ...
# 995   Vivaan Verma   32     POL973107
# 996    Arjun Mehta   67     POL755200
# 997  Krishna Gupta   27     POL970351
# 998   Pranav Verma   49     POL343885
# 999  Reyansh Patel   72     POL418617
#
# [1000 rows x 3 columns]

# %%
df
# Out:
#      Patient_ID   Patient_Name  Age                         Email  \
# 0             1  Krishna Reddy   22  krishna.reddy835@outlook.com
# 1             2    Arjun Gupta   40    arjun.gupta570@outlook.com
# 2             3   Vivaan Singh   51      vivaan.singh72@yahoo.com
# 3             4    Arjun Kumar   36    arjun.kumar883@outlook.com
# 4             5  Krishna Verma   23    krishna.verma273@yahoo.com
# ..          ...            ...  ...                           ...
# 995         996   Vivaan Verma   32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta   67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta   27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma   49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel   72    reyansh.patel612@yahoo.com
#
#     Policy_Number Policy_Type  year
# 0       POL602544    Platinum  2025
# 1       POL856642        Gold  2025
# 2       POL512045    Platinum  2025
# ...

# %%
## get all the columns along with 20 to 30 rowns numbers

df.iloc[20:31,:] ## iloc -- index location 

## syntax of iloc is 

#dataframe.iloc[range_rows, range_columns]
# Out:
#     Patient_ID    Patient_Name  Age                          Email  \
# 20          21    Vihaan Kumar   73    vihaan.kumar651@outlook.com
# 21          22       Sai Verma   60       sai.verma422@outlook.com
# 22          23    Vihaan Verma   43    vihaan.verma972@outlook.com
# 23          24    Aditya Gupta   37      aditya.gupta843@yahoo.com
# 24          25    Pranav Kumar   25      pranav.kumar649@yahoo.com
# 25          26   Aditya Sharma   61     aditya.sharma1@outlook.com
# 26          27     Arjun Kumar   43     arjun.kumar396@outlook.com
# 27          28     Arjun Joshi   70       arjun.joshi601@gmail.com
# 28          29    Aditya Joshi   41      aditya.joshi111@yahoo.com
# 29          30    Vivaan Patel   44    vivaan.patel698@outlook.com
# 30          31  Reyansh Sharma   48  reyansh.sharma154@outlook.com
#
#    Policy_Number Policy_Type  year
# 20     POL996694       Basic  2025
# 21     POL752117     Premium  2025
# 22     POL926834    Platinum  2025
# ...

# %%
## get records from 15 to 25 index for column --> Patient_name , Policy_Type

df.iloc[15:26,[1,5]]
# Out:
#      Patient_Name Policy_Type
# 15   Aditya Mehta        Gold
# 16  Reyansh Joshi        Gold
# 17   Vivaan Verma     Premium
# 18   Pranav Singh       Basic
# 19      Sai Patel     Premium
# 20   Vihaan Kumar       Basic
# 21      Sai Verma     Premium
# 22   Vihaan Verma    Platinum
# 23   Aditya Gupta        Gold
# 24   Pranav Kumar    Platinum
# 25  Aditya Sharma     Premium

# %%
df.loc[15:25,['Patient_Name','Policy_Type']]

## loc ---> location 

#syntax 

#dataframe.loc[range_row, [name of the columns]]
# Out:
#      Patient_Name Policy_Type
# 15   Aditya Mehta        Gold
# 16  Reyansh Joshi        Gold
# 17   Vivaan Verma     Premium
# 18   Pranav Singh       Basic
# 19      Sai Patel     Premium
# 20   Vihaan Kumar       Basic
# 21      Sai Verma     Premium
# 22   Vihaan Verma    Platinum
# 23   Aditya Gupta        Gold
# 24   Pranav Kumar    Platinum
# 25  Aditya Sharma     Premium

# %%
df
# Out:
#      Patient_ID   Patient_Name  Age                         Email  \
# 0             1  Krishna Reddy   22  krishna.reddy835@outlook.com
# 1             2    Arjun Gupta   40    arjun.gupta570@outlook.com
# 2             3   Vivaan Singh   51      vivaan.singh72@yahoo.com
# 3             4    Arjun Kumar   36    arjun.kumar883@outlook.com
# 4             5  Krishna Verma   23    krishna.verma273@yahoo.com
# ..          ...            ...  ...                           ...
# 995         996   Vivaan Verma   32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta   67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta   27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma   49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel   72    reyansh.patel612@yahoo.com
#
#     Policy_Number Policy_Type  year
# 0       POL602544    Platinum  2025
# 1       POL856642        Gold  2025
# 2       POL512045    Platinum  2025
# ...

# %%
df.loc[45:65,['Patient_Name','Email']]
# Out:
#      Patient_Name                        Email
# 45  Vivaan Sharma   vivaan.sharma856@gmail.com
# 46  Krishna Gupta   krishna.gupta187@yahoo.com
# 47   Vihaan Patel  vihaan.patel412@outlook.com
# 48    Arjun Verma     arjun.verma648@gmail.com
# 49   Pranav Joshi  pranav.joshi515@outlook.com
# 50   Pranav Singh  pranav.singh983@outlook.com
# 51   Vivaan Reddy    vivaan.reddy408@gmail.com
# 52   Pranav Gupta    pranav.gupta629@gmail.com
# 53   Vihaan Verma    vihaan.verma629@yahoo.com
# 54   Ishaan Singh    ishaan.singh626@gmail.com
# 55   Vivaan Mehta    vivaan.mehta132@yahoo.com
# 56  Aditya Sharma   aditya.sharma908@gmail.com
# 57   Pranav Gupta  pranav.gupta267@outlook.com
# 58   Vihaan Gupta  vihaan.gupta726@outlook.com
# 59  Reyansh Singh  reyansh.singh19@outlook.com
# 60  Krishna Patel   krishna.patel524@yahoo.com
# 61   Ishaan Yadav  ishaan.yadav693@outlook.com
# 62   Arjun Sharma  arjun.sharma656@outlook.com
# 63   Vivaan Gupta     vivaan.gupta69@gmail.com
# ...

# %%
## rename the columns

df.columns
# Out:
# Index(['Patient_ID', 'Patient_Name', 'Age', 'Email', 'Policy_Number',
#        'Policy_Type', 'year'],
#       dtype='object')

# %%
df.rename(columns={'Age':'Patient_Age'}, inplace=True)

# %%
df
# Out:
#      Patient_ID   Patient_Name  Patient_Age                         Email  \
# 0             1  Krishna Reddy           22  krishna.reddy835@outlook.com
# 1             2    Arjun Gupta           40    arjun.gupta570@outlook.com
# 2             3   Vivaan Singh           51      vivaan.singh72@yahoo.com
# 3             4    Arjun Kumar           36    arjun.kumar883@outlook.com
# 4             5  Krishna Verma           23    krishna.verma273@yahoo.com
# ..          ...            ...          ...                           ...
# 995         996   Vivaan Verma           32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta           67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta           27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma           49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel           72    reyansh.patel612@yahoo.com
#
#     Policy_Number Policy_Type  year
# 0       POL602544    Platinum  2025
# ...

# %%
df.rename(columns={"Email":"Patient_Email","Policy_Number":"Policy_Num"})
# Out:
#      Patient_ID   Patient_Name  Patient_Age                 Patient_Email  \
# 0             1  Krishna Reddy           22  krishna.reddy835@outlook.com
# 1             2    Arjun Gupta           40    arjun.gupta570@outlook.com
# 2             3   Vivaan Singh           51      vivaan.singh72@yahoo.com
# 3             4    Arjun Kumar           36    arjun.kumar883@outlook.com
# 4             5  Krishna Verma           23    krishna.verma273@yahoo.com
# ..          ...            ...          ...                           ...
# 995         996   Vivaan Verma           32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta           67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta           27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma           49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel           72    reyansh.patel612@yahoo.com
#
#     Policy_Num Policy_Type  year
# 0    POL602544    Platinum  2025
# ...

# %%
df.drop(columns=['Patient_ID','year'])
# Out:
#       Patient_Name  Patient_Age                         Email Policy_Number  \
# 0    Krishna Reddy           22  krishna.reddy835@outlook.com     POL602544
# 1      Arjun Gupta           40    arjun.gupta570@outlook.com     POL856642
# 2     Vivaan Singh           51      vivaan.singh72@yahoo.com     POL512045
# 3      Arjun Kumar           36    arjun.kumar883@outlook.com     POL132724
# 4    Krishna Verma           23    krishna.verma273@yahoo.com     POL060110
# ..             ...          ...                           ...           ...
# 995   Vivaan Verma           32     vivaan.verma316@gmail.com     POL973107
# 996    Arjun Mehta           67    arjun.mehta768@outlook.com     POL755200
# 997  Krishna Gupta           27  krishna.gupta488@outlook.com     POL970351
# 998   Pranav Verma           49      pranav.verma36@yahoo.com     POL343885
# 999  Reyansh Patel           72    reyansh.patel612@yahoo.com     POL418617
#
#     Policy_Type
# 0      Platinum
# 1          Gold
# ...

# %%
df
# Out:
#      Patient_ID   Patient_Name  Patient_Age                         Email  \
# 0             1  Krishna Reddy           22  krishna.reddy835@outlook.com
# 1             2    Arjun Gupta           40    arjun.gupta570@outlook.com
# 2             3   Vivaan Singh           51      vivaan.singh72@yahoo.com
# 3             4    Arjun Kumar           36    arjun.kumar883@outlook.com
# 4             5  Krishna Verma           23    krishna.verma273@yahoo.com
# ..          ...            ...          ...                           ...
# 995         996   Vivaan Verma           32     vivaan.verma316@gmail.com
# 996         997    Arjun Mehta           67    arjun.mehta768@outlook.com
# 997         998  Krishna Gupta           27  krishna.gupta488@outlook.com
# 998         999   Pranav Verma           49      pranav.verma36@yahoo.com
# 999        1000  Reyansh Patel           72    reyansh.patel612@yahoo.com
#
#     Policy_Number Policy_Type  year
# 0       POL602544    Platinum  2025
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.set_index('Patient_ID', inplace=True)

# %%
df
# Out:
#              Patient_Name  Patient_Age                         Email  \
# Patient_ID
# 1           Krishna Reddy           22  krishna.reddy835@outlook.com
# 2             Arjun Gupta           40    arjun.gupta570@outlook.com
# 3            Vivaan Singh           51      vivaan.singh72@yahoo.com
# 4             Arjun Kumar           36    arjun.kumar883@outlook.com
# 5           Krishna Verma           23    krishna.verma273@yahoo.com
# ...                   ...          ...                           ...
# 996          Vivaan Verma           32     vivaan.verma316@gmail.com
# 997           Arjun Mehta           67    arjun.mehta768@outlook.com
# 998         Krishna Gupta           27  krishna.gupta488@outlook.com
# 999          Pranav Verma           49      pranav.verma36@yahoo.com
# 1000        Reyansh Patel           72    reyansh.patel612@yahoo.com
#
#            Policy_Number Policy_Type  year
# Patient_ID
# 1              POL602544    Platinum  2025
# ...

# %%
df.shape
# Out:
# (1000, 6)

# %%
df=df.reset_index()

# %%
df.shape
# Out:
# (1000, 7)

# %%
df.head()
# Out:
#    Patient_ID   Patient_Name  Patient_Age                         Email  \
# 0           1  Krishna Reddy           22  krishna.reddy835@outlook.com
# 1           2    Arjun Gupta           40    arjun.gupta570@outlook.com
# 2           3   Vivaan Singh           51      vivaan.singh72@yahoo.com
# 3           4    Arjun Kumar           36    arjun.kumar883@outlook.com
# 4           5  Krishna Verma           23    krishna.verma273@yahoo.com
#
#   Policy_Number Policy_Type  year
# 0     POL602544    Platinum  2025
# 1     POL856642        Gold  2025
# 2     POL512045    Platinum  2025
# 3     POL132724        Gold  2025
# 4     POL060110        Gold  2025

# %%
df.sort_values(by='Patient_Age',ascending=False,inplace=True)

# %%
df
# Out:
#      Patient_ID   Patient_Name  Patient_Age                         Email  \
# 79           80  Krishna Kumar           80    krishna.kumar274@yahoo.com
# 117         118      Sai Yadav           80        sai.yadav586@gmail.com
# 74           75      Sai Joshi           80      sai.joshi804@outlook.com
# 603         604   Pranav Patel           80     pranav.patel329@yahoo.com
# 590         591      Sai Reddy           80        sai.reddy717@yahoo.com
# ..          ...            ...          ...                           ...
# 329         330      Sai Patel           18      sai.patel488@outlook.com
# 801         802    Arjun Reddy           18    arjun.reddy613@outlook.com
# 799         800  Reyansh Yadav           18  reyansh.yadav630@outlook.com
# 263         264      Sai Patel           18        sai.patel677@gmail.com
# 479         480   Vihaan Joshi           18     vihaan.joshi116@gmail.com
#
#     Policy_Number Policy_Type  year
# 79      POL078226    Platinum  2025
# ...

# %%
## get the unique type of policy data has
df['Policy_Type'].unique()
# Out:
# array(['Platinum', 'Premium', 'Gold', 'Basic'], dtype=object)

# %%
## get the number of unique policy data has
df['Policy_Type'].nunique()
# Out:
# 4

# %%
df['Patient_Age'].unique()
# Out:
# array([80, 79, 78, 77, 76, 75, 74, 73, 72, 71, 70, 69, 68, 67, 66, 65, 64,
#        63, 62, 61, 60, 59, 58, 57, 56, 55, 54, 53, 52, 51, 50, 49, 48, 47,
#        46, 45, 44, 43, 42, 41, 40, 39, 38, 37, 36, 35, 34, 33, 32, 31, 30,
#        29, 28, 27, 26, 25, 24, 23, 22, 21, 20, 19, 18], dtype=int64)

# %%
df['Patient_Age'].nunique()
# Out:
# 63

# %%
df
# Out:
#      Patient_ID   Patient_Name  Patient_Age                         Email  \
# 79           80  Krishna Kumar           80    krishna.kumar274@yahoo.com
# 117         118      Sai Yadav           80        sai.yadav586@gmail.com
# 74           75      Sai Joshi           80      sai.joshi804@outlook.com
# 603         604   Pranav Patel           80     pranav.patel329@yahoo.com
# 590         591      Sai Reddy           80        sai.reddy717@yahoo.com
# ..          ...            ...          ...                           ...
# 329         330      Sai Patel           18      sai.patel488@outlook.com
# 801         802    Arjun Reddy           18    arjun.reddy613@outlook.com
# 799         800  Reyansh Yadav           18  reyansh.yadav630@outlook.com
# 263         264      Sai Patel           18        sai.patel677@gmail.com
# 479         480   Vihaan Joshi           18     vihaan.joshi116@gmail.com
#
#     Policy_Number Policy_Type  year
# 79      POL078226    Platinum  2025
# ...

# %%
Patients_2026_date
# Out:
#      Patient_ID  Patient_Name  Age                        Email Policy_Number  \
# 0          1001   Aarav Mehta   78     aarav.mehta384@yahoo.com     POL625423
# 1          1002   Aarav Verma   32     aarav.verma271@yahoo.com     POL930599
# 2          1003  Vihaan Verma   40  vihaan.verma345@outlook.com     POL456865
# 3          1004  Aditya Mehta   18  aditya.mehta579@outlook.com     POL982259
# 4          1005   Aarav Singh   39   aarav.singh126@outlook.com     POL742545
# ..          ...           ...  ...                          ...           ...
# 995        1996   Aarav Mehta   31    aarav.mehta63@outlook.com     POL748260
# 996        1997  Ishaan Yadav   59  ishaan.yadav830@outlook.com     POL725846
# 997        1998  Aarav Sharma   72     aarav.sharma12@yahoo.com     POL362369
# 998        1999  Ishaan Joshi   65   ishaan.joshi92@outlook.com     POL921223
# 999        2000  Vivaan Singh   57    vivaan.singh214@yahoo.com     POL309917
#
#     Policy_Type  Year
# ...

# %%
pd.concat([df,Patients_2026_date])
# Out:
#      Patient_ID   Patient_Name  Patient_Age                        Email  \
# 79           80  Krishna Kumar         80.0   krishna.kumar274@yahoo.com
# 117         118      Sai Yadav         80.0       sai.yadav586@gmail.com
# 74           75      Sai Joshi         80.0     sai.joshi804@outlook.com
# 603         604   Pranav Patel         80.0    pranav.patel329@yahoo.com
# 590         591      Sai Reddy         80.0       sai.reddy717@yahoo.com
# ..          ...            ...          ...                          ...
# 995        1996    Aarav Mehta          NaN    aarav.mehta63@outlook.com
# 996        1997   Ishaan Yadav          NaN  ishaan.yadav830@outlook.com
# 997        1998   Aarav Sharma          NaN     aarav.sharma12@yahoo.com
# 998        1999   Ishaan Joshi          NaN   ishaan.joshi92@outlook.com
# 999        2000   Vivaan Singh          NaN    vivaan.singh214@yahoo.com
#
#     Policy_Number Policy_Type    year   Age    Year
# ...

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Patient_Name', 'Patient_Age', 'Email', 'Policy_Number',
#        'Policy_Type', 'year'],
#       dtype='object')

# %%
Patients_2026_date.columns
# Out:
# Index(['Patient_ID', 'Patient_Name', 'Age', 'Email', 'Policy_Number',
#        'Policy_Type', 'Year'],
#       dtype='object')

# %%
Patients_2026_date.rename(columns={'Age':'Patient_Age','Year':'year'}, inplace=True)

# %%
Patients_2026_date.columns
# Out:
# Index(['Patient_ID', 'Patient_Name', 'Patient_Age', 'Email', 'Policy_Number',
#        'Policy_Type', 'year'],
#       dtype='object')

# %%
patient_data=pd.concat([df,Patients_2026_date],axis=0)

# %%
patient_data.shape
# Out:
# (2000, 7)

# %%
patient_data.reset_index(inplace=True)

# %%
patient_data.head()
# Out:
#    index  Patient_ID   Patient_Name  Patient_Age                       Email  \
# 0     79          80  Krishna Kumar           80  krishna.kumar274@yahoo.com
# 1    117         118      Sai Yadav           80      sai.yadav586@gmail.com
# 2     74          75      Sai Joshi           80    sai.joshi804@outlook.com
# 3    603         604   Pranav Patel           80   pranav.patel329@yahoo.com
# 4    590         591      Sai Reddy           80      sai.reddy717@yahoo.com
#
#   Policy_Number Policy_Type  year
# 0     POL078226    Platinum  2025
# 1     POL034543    Platinum  2025
# 2     POL875971     Premium  2025
# 3     POL097005     Premium  2025
# 4     POL640591     Premium  2025

# %%
## drop the column index

patient_data.drop(columns='index', inplace=True)

# %%
patient_data.head()
# Out:
#    Patient_ID   Patient_Name  Patient_Age                       Email  \
# 0          80  Krishna Kumar           80  krishna.kumar274@yahoo.com
# 1         118      Sai Yadav           80      sai.yadav586@gmail.com
# 2          75      Sai Joshi           80    sai.joshi804@outlook.com
# 3         604   Pranav Patel           80   pranav.patel329@yahoo.com
# 4         591      Sai Reddy           80      sai.reddy717@yahoo.com
#
#   Policy_Number Policy_Type  year
# 0     POL078226    Platinum  2025
# 1     POL034543    Platinum  2025
# 2     POL875971     Premium  2025
# 3     POL097005     Premium  2025
# 4     POL640591     Premium  2025

# %%
policy_file_path = r"C:\Users\prash\Desktop\Python_for_all_YT_Playlist\data\policy_data.xlsx"

# %%
policy_data= pd.read_excel(policy_file_path)

# %%
policy_data.shape
# Out:
# (2000, 4)

# %%
policy_data
# Out:
#      Policy_Number        Provider_Name  Coverage_Amount  Start_Year
# 0        POL602544  New India Assurance           586130        2025
# 1        POL856642             Max Bupa           216864        2024
# 2        POL512045  New India Assurance           218977        2025
# 3        POL132724             Max Bupa           842430        2025
# 4        POL060110          Star Health           806879        2025
# ...            ...                  ...              ...         ...
# 1995     POL748260          Star Health           484092        2024
# 1996     POL725846          Star Health           579515        2023
# 1997     POL362369             Max Bupa           644437        2023
# 1998     POL921223             Max Bupa           965221        2024
# 1999     POL309917        ICICI Lombard           213392        2024
#
# [2000 rows x 4 columns]

# %%
##pd.concat([patient_data,policy_data],axis=1)# you can't use cancatination on relational data. beciase cancat perform based on index match

# %%
## Merge

patient_data.merge(policy_data,how='left',on='Policy_Number')
# Out:
#       Patient_ID   Patient_Name  Patient_Age                        Email  \
# 0             80  Krishna Kumar           80   krishna.kumar274@yahoo.com
# 1            118      Sai Yadav           80       sai.yadav586@gmail.com
# 2             75      Sai Joshi           80     sai.joshi804@outlook.com
# 3            604   Pranav Patel           80    pranav.patel329@yahoo.com
# 4            591      Sai Reddy           80       sai.reddy717@yahoo.com
# ...          ...            ...          ...                          ...
# 1997        1996    Aarav Mehta           31    aarav.mehta63@outlook.com
# 1998        1997   Ishaan Yadav           59  ishaan.yadav830@outlook.com
# 1999        1998   Aarav Sharma           72     aarav.sharma12@yahoo.com
# 2000        1999   Ishaan Joshi           65   ishaan.joshi92@outlook.com
# 2001        2000   Vivaan Singh           57    vivaan.singh214@yahoo.com
#
#      Policy_Number Policy_Type  year  Provider_Name  Coverage_Amount  \
# ...

# %%
## case 2 -- if both the data fame common columns name is not same, what ypu will do in this case?

# %%
policy_data.rename(columns ={'Policy_Number':'policy_number'},inplace=True)

# %%
policy_data.head()
# Out:
#   policy_number        Provider_Name  Coverage_Amount  Start_Year
# 0     POL602544  New India Assurance           586130        2025
# 1     POL856642             Max Bupa           216864        2024
# 2     POL512045  New India Assurance           218977        2025
# 3     POL132724             Max Bupa           842430        2025
# 4     POL060110          Star Health           806879        2025

# %%
patient_data=patient_data.merge(policy_data,how='left',left_on='Policy_Number',right_on='policy_number')

# %%
patient_data
# Out:
#       Patient_ID   Patient_Name  Patient_Age                        Email  \
# 0             80  Krishna Kumar           80   krishna.kumar274@yahoo.com
# 1            118      Sai Yadav           80       sai.yadav586@gmail.com
# 2             75      Sai Joshi           80     sai.joshi804@outlook.com
# 3            604   Pranav Patel           80    pranav.patel329@yahoo.com
# 4            591      Sai Reddy           80       sai.reddy717@yahoo.com
# ...          ...            ...          ...                          ...
# 1997        1996    Aarav Mehta           31    aarav.mehta63@outlook.com
# 1998        1997   Ishaan Yadav           59  ishaan.yadav830@outlook.com
# 1999        1998   Aarav Sharma           72     aarav.sharma12@yahoo.com
# 2000        1999   Ishaan Joshi           65   ishaan.joshi92@outlook.com
# 2001        2000   Vivaan Singh           57    vivaan.singh214@yahoo.com
#
#      Policy_Number Policy_Type  year policy_number  Provider_Name  \
# ...

# %%
patient_data.drop(columns={'policy_number'}, inplace=True)

# %%
patient_data.head()
# Out:
#    Patient_ID   Patient_Name  Patient_Age                       Email  \
# 0          80  Krishna Kumar           80  krishna.kumar274@yahoo.com
# 1         118      Sai Yadav           80      sai.yadav586@gmail.com
# 2          75      Sai Joshi           80    sai.joshi804@outlook.com
# 3         604   Pranav Patel           80   pranav.patel329@yahoo.com
# 4         591      Sai Reddy           80      sai.reddy717@yahoo.com
#
#   Policy_Number Policy_Type  year Provider_Name  Coverage_Amount  Start_Year
# 0     POL078226    Platinum  2025     HDFC Ergo           851420        2026
# 1     POL034543    Platinum  2025   Star Health           829205        2023
# 2     POL875971     Premium  2025   Star Health           659481        2025
# 3     POL097005     Premium  2025     HDFC Ergo           135569        2026
# 4     POL640591     Premium  2025     HDFC Ergo           954316        2026

# %%
patient_data.shape
# Out:
# (2002, 10)

# %%
## filter out patient data where policy type is basic

patient_data[patient_data["Policy_Type"]=="Basic"]
# Out:
#       Patient_ID   Patient_Name  Patient_Age                         Email  \
# 17           340   Ishaan Kumar           79   ishaan.kumar451@outlook.com
# 23           388    Arjun Reddy           79      arjun.reddy866@yahoo.com
# 25           295   Ishaan Gupta           79   ishaan.gupta980@outlook.com
# 30           384    Aarav Singh           78      aarav.singh557@yahoo.com
# 31           173  Krishna Yadav           78  krishna.yadav117@outlook.com
# ...          ...            ...          ...                           ...
# 1978        1977   Vivaan Singh           43     vivaan.singh140@gmail.com
# 1979        1978   Vivaan Patel           56     vivaan.patel152@gmail.com
# 1994        1993   Pranav Mehta           66     pranav.mehta382@yahoo.com
# 1996        1995  Reyansh Joshi           52    reyansh.joshi728@gmail.com
# 1998        1997   Ishaan Yadav           59   ishaan.yadav830@outlook.com
#
# ...

# %%
## how many patient above 40 has taken policy from ICICI Lombard
patient_data[(patient_data['Patient_Age']>40) & (patient_data['Provider_Name']=='ICICI Lombard')  ].counT()
# Out:
# Patient_ID         270
# Patient_Name       270
# Patient_Age        270
# Email              270
# Policy_Number      270
# Policy_Type        270
# year               270
# Provider_Name      270
# Coverage_Amount    270
# Start_Year         270
# dtype: int64

# %%
## how many patient above age 50 taken insurence from Icici or HDFC

patient_data[(patient_data['Patient_Age']>50) & 
             ((patient_data['Provider_Name']=='ICICI Lombard') | 
              (patient_data['Provider_Name']=='HDFC Ergo'))  ].count()
# Out:
# Patient_ID         379
# Patient_Name       379
# Patient_Age        379
# Email              379
# Policy_Number      379
# Policy_Type        379
# year               379
# Provider_Name      379
# Coverage_Amount    379
# Start_Year         379
# dtype: int64

# %%
## how many patient has invested amount b/w 200000 to 400000 during year 2023 and 2024 in insurence
    
patient_data[(patient_data['Coverage_Amount'].between(200000, 400000)) & (patient_data['Start_Year'].isin([2023,2024]))]['Patient_ID'].count()
# Out:
# 248

# %%
## how to find there is duplicate in the data or not 

patient_data['Patient_ID'].value_counts()
# Out:
# Patient_ID
# 1173    2
# 1581    2
# 1330    1
# 1342    1
# 1341    1
#        ..
# 24      1
# 353     1
# 176     1
# 895     1
# 2000    1
# Name: count, Length: 2000, dtype: int64

# %%
patient_data[patient_data['Patient_ID'].isin([1173,1581])]
# Out:
#       Patient_ID   Patient_Name  Patient_Age                         Email  \
# 1172        1173  Krishna Mehta           59  krishna.mehta687@outlook.com
# 1173        1173  Krishna Mehta           59  krishna.mehta687@outlook.com
# 1581        1581   Aditya Patel           31     aditya.patel676@yahoo.com
# 1582        1581   Aditya Patel           31     aditya.patel676@yahoo.com
#
#      Policy_Number Policy_Type  year Provider_Name  Coverage_Amount  \
# 1172     POL071964     Premium  2026     HDFC Ergo           169951
# 1173     POL071964     Premium  2026      Max Bupa           718566
# 1581     POL071964     Premium  2026     HDFC Ergo           169951
# 1582     POL071964     Premium  2026      Max Bupa           718566
#
#       Start_Year
# 1172        2023
# 1173        2025
# 1581        2023
# 1582        2025

# %%
patient_data.drop_duplicates(subset='Patient_ID',keep='first', inplace=True)

# %%
patient_data['Patient_ID'].duplicated().sum()
# Out:
# 0

# %%
patient_data['Coverage_Amount'].unique()
# Out:
# array([851420, 829205, 659481, ..., 644437, 965221, 213392], dtype=int64)

# %%
## how many patient has invested amount b/w 200000 to 400000 during year 2023 and 2024 in insurence
    
patient_data[(patient_data['Coverage_Amount'].between(200000, 400000)) & (patient_data['Start_Year'].isin([2023,2024]))]['Patient_ID'].count()
# Out:
# 248

# %%
patient_data.head()
# Out:
#    Patient_ID   Patient_Name  Patient_Age                       Email  \
# 0          80  Krishna Kumar           80  krishna.kumar274@yahoo.com
# 1         118      Sai Yadav           80      sai.yadav586@gmail.com
# 2          75      Sai Joshi           80    sai.joshi804@outlook.com
# 3         604   Pranav Patel           80   pranav.patel329@yahoo.com
# 4         591      Sai Reddy           80      sai.reddy717@yahoo.com
#
#   Policy_Number Policy_Type  year Provider_Name  Coverage_Amount  Start_Year
# 0     POL078226    Platinum  2025     HDFC Ergo           851420        2026
# 1     POL034543    Platinum  2025   Star Health           829205        2023
# 2     POL875971     Premium  2025   Star Health           659481        2025
# 3     POL097005     Premium  2025     HDFC Ergo           135569        2026
# 4     POL640591     Premium  2025     HDFC Ergo           954316        2026

# %%
patient_data.query("Coverage_Amount.between(200000,400000) and Start_Year.isin([2023,2024])")
# Out:
#       Patient_ID   Patient_Name  Patient_Age                         Email  \
# 12           471   Aditya Reddy           80   aditya.reddy246@outlook.com
# 16           147   Aditya Kumar           79     aditya.kumar636@gmail.com
# 17           340   Ishaan Kumar           79   ishaan.kumar451@outlook.com
# 18           218   Vivaan Gupta           79   vivaan.gupta585@outlook.com
# 20           635    Aarav Gupta           79    aarav.gupta587@outlook.com
# ...          ...            ...          ...                           ...
# 1958        1957   Pranav Gupta           60     pranav.gupta933@yahoo.com
# 1959        1958   Vihaan Patel           39     vihaan.patel448@yahoo.com
# 1960        1959  Reyansh Gupta           74  reyansh.gupta307@outlook.com
# 1993        1992    Aarav Singh           71      aarav.singh994@gmail.com
# 2001        2000   Vivaan Singh           57     vivaan.singh214@yahoo.com
#
# ...

# %%
## filter out patient details whos age is grater than 40 and taken Premium policy

patient_data.query("Patient_Age>40 and Policy_Type == 'Premium'" )
# Out:
#       Patient_ID   Patient_Name  Patient_Age                       Email  \
# 2             75      Sai Joshi           80    sai.joshi804@outlook.com
# 3            604   Pranav Patel           80   pranav.patel329@yahoo.com
# 4            591      Sai Reddy           80      sai.reddy717@yahoo.com
# 7             71     Sai Sharma           80     sai.sharma866@yahoo.com
# 8            808   Ishaan Verma           80   ishaan.verma174@yahoo.com
# ...          ...            ...          ...                         ...
# 1980        1979      Sai Singh           60    sai.singh449@outlook.com
# 1982        1981      Sai Verma           79      sai.verma933@gmail.com
# 1986        1985   Vihaan Mehta           80    vihaan.mehta18@yahoo.com
# 1991        1990  Krishna Yadav           49  krishna.yadav340@yahoo.com
# 2000        1999   Ishaan Joshi           65  ishaan.joshi92@outlook.com
#
#      Policy_Number Policy_Type  year Provider_Name  Coverage_Amount  \
# ...

# %%
## how many patient email id contains gmail.com

patient_data[patient_data["Email"].str.contains('gmail.com')]['Patient_ID'].count()
# Out:
# 632

# %%
## how many patients email start with AR
patient_data[patient_data["Email"].str.startswith('ar')]
# Out:
#       Patient_ID  Patient_Name  Patient_Age                        Email  \
# 23           388   Arjun Reddy           79     arjun.reddy866@yahoo.com
# 32           568   Arjun Singh           78     arjun.singh955@gmail.com
# 47           823  Arjun Sharma           77  arjun.sharma553@outlook.com
# 65           815   Arjun Yadav           76     arjun.yadav841@yahoo.com
# 74           766   Arjun Joshi           76     arjun.joshi809@yahoo.com
# ...          ...           ...          ...                          ...
# 1936        1935   Arjun Joshi           41     arjun.joshi408@gmail.com
# 1939        1938   Arjun Patel           51     arjun.patel163@yahoo.com
# 1940        1939   Arjun Yadav           55     arjun.yadav996@yahoo.com
# 1963        1962   Arjun Singh           76      arjun.singh26@gmail.com
# 1992        1991   Arjun Mehta           77     arjun.mehta725@yahoo.com
#
#      Policy_Number Policy_Type  year        Provider_Name  Coverage_Amount  \
# ...

# %%
patient_data[patient_data["Email"].str.startswith('ar')]['Patient_ID'].count()
# Out:
# 190

# %%
## how many patient last name end with Singh
patient_data[patient_data["Patient_Name"].str.endswith('Singh')]
# Out:
#       Patient_ID  Patient_Name  Patient_Age                        Email  \
# 5            825  Aditya Singh           80  aditya.singh435@outlook.com
# 27            99  Aditya Singh           79    aditya.singh601@yahoo.com
# 29           502  Vihaan Singh           79    vihaan.singh558@gmail.com
# 30           384   Aarav Singh           78     aarav.singh557@yahoo.com
# 32           568   Arjun Singh           78     arjun.singh955@gmail.com
# ...          ...           ...          ...                          ...
# 1978        1977  Vivaan Singh           43    vivaan.singh140@gmail.com
# 1980        1979     Sai Singh           60     sai.singh449@outlook.com
# 1988        1987  Aditya Singh           26    aditya.singh106@yahoo.com
# 1993        1992   Aarav Singh           71     aarav.singh994@gmail.com
# 2001        2000  Vivaan Singh           57    vivaan.singh214@yahoo.com
#
#      Policy_Number Policy_Type  year        Provider_Name  Coverage_Amount  \
# ...

# %%
patient_data[patient_data["Patient_Name"].str.endswith('Singh')]['Patient_ID'].count()
# Out:
# 227
